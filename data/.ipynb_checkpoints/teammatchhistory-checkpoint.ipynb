# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#dtype warning for columns (12,18,24,25,26,27,29,47,60)
dtype_columns = {"Level":float, "CS in Team's Jungle":float, "Vision Score":float, "Wards placed":float, "Wards destroyed":float, "Control Wards Purchased":float, "VSPM":float, "GD@15":float, "Total damage taken":float}

# %%
# stops pandas from interpreting NA (the region) as missing value NaN
df = pd.read_csv("combined_match_stats.csv", keep_default_na=False,na_values=[""],low_memory=False)

# %%
df.head()
# Out:
#    GameID          Team Result Game Time  Side  Patch        Tournament  \
# 0   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 1   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 2   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 3   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 4   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
#
#          Date Region Champion   Player     Role  Level  Kills  Deaths  \
# 0  2025-01-12     CN   Ksante  Breathe      TOP   18.0      4       0
# 1  2025-01-12     CN    Viego     Tian   JUNGLE   17.0      4       0
# 2  2025-01-12     CN   Aurora   xiaohu      MID   18.0      5       1
# 3  2025-01-12     CN     Ashe    Light      ADC   16.0      3       2
# 4  2025-01-12     CN    Braum     Hang  SUPPORT   14.0      1       2
#
#    Assists          KDA   CS  CS in Team's Jungle  CS in Enemy Jungle  CSM  \
# 0        3  Perfect KDA  314                  4.0                 NaN  8.9
# 1        5  Perfect KDA  273                238.0                 NaN  7.7
# 2        8           13  286                  4.0                 NaN  8.1
# 3        6          4.5  305                 21.0                 NaN  8.6
# 4       11            6   38                  0.0                 NaN  1.1
#
#    Golds  GPM  GOLD%  Vision Score  Wards placed  Wards destroyed  \
# 0  14706  416  21.2%         31.78          14.0              3.0
# 1  14586  412    21%         54.74          13.0             14.0
# 2  15720  444  22.6%         42.96          11.0             11.0
# 3  14688  415  21.1%         57.29           9.0             17.0
# 4   9762  276  14.1%        144.10          67.0             20.0
#
#    Control Wards Purchased  Detector Wards Placed  VSPM   WPM  VWPM  WCPM  \
# 0                      5.0                    NaN  0.90  0.40  0.14  0.08
# 1                     12.0                    NaN  1.55  0.37  0.34  0.40
# 2                      7.0                    NaN  1.21  0.31  0.20  0.31
# 3                      3.0                    NaN  1.62  0.25  0.08  0.48
# 4                     19.0                    NaN  4.07  1.89  0.54  0.57
#
#      VS%  Total damage to Champion  Physical Damage  Magic Damage  \
# 0   9.6%                   9830.40          7914.28       1012.28
# 1  16.5%                  10013.26          8758.59       1070.67
# 2    13%                  37571.06          1077.96      35183.30
# 3  17.3%                  15603.29         14094.30       1508.99
# 4  43.6%                   6292.02           465.85       5826.17
#
#    True Damage   DPM   DMG%  K+A Per Minute    KP%  Solo kills  Double kills  \
# 0       903.84   278  12.4%            0.20  41.2%         NaN           NaN
# 1       184.00   283  12.6%            0.25  52.9%         NaN           NaN
# 2      1309.80  1062  47.4%            0.37  76.5%         NaN           NaN
# 3         0.00   441  19.7%            0.25  52.9%         NaN           NaN
# 4         0.00   178   7.9%            0.34  70.6%         NaN           NaN
#
#    Triple kills  Quadra kills  Penta kills   GD@15  CSD@15  XPD@15  LVLD@15  \
# 0           NaN           NaN          NaN  -600.0     NaN     NaN      NaN
# 1           NaN           NaN          NaN   528.0     NaN     NaN      NaN
# 2           NaN           NaN          NaN  1072.0     NaN     NaN      NaN
# 3           NaN           NaN          NaN  -199.0     NaN     NaN      NaN
# 4           NaN           NaN          NaN   250.0     NaN     NaN      NaN
#
#    Objectives Stolen  Damage dealt to turrets  Damage dealt to buildings  \
# 0                NaN                      NaN                        NaN
# 1                NaN                      NaN                        NaN
# 2                NaN                      NaN                        NaN
# 3                NaN                      NaN                        NaN
# 4                NaN                      NaN                        NaN
#
#    Total heal  Total Heals On Teammates  Damage self mitigated  \
# 0         NaN                       NaN                    NaN
# 1         NaN                       NaN                    NaN
# 2         NaN                       NaN                    NaN
# 3         NaN                       NaN                    NaN
# 4         NaN                       NaN                    NaN
#
#    Total Damage Shielded On Teammates  Time ccing others  Total Time CC Dealt  \
# 0                                 NaN                NaN                  NaN
# 1                                 NaN                NaN                  NaN
# 2                                 NaN                NaN                  NaN
# 3                                 NaN                NaN                  NaN
# 4                                 NaN                NaN                  NaN
#
#    Total damage taken  Total Time Spent Dead  Consumables purchased  \
# 0             26434.7                    NaN                    NaN
# 1             42723.7                    NaN                    NaN
# 2             16880.7                    NaN                    NaN
# 3             15290.8                    NaN                    NaN
# 4             17962.1                    NaN                    NaN
#
#    Items Purchased  Shutdown bounty collected  Shutdown bounty lost
# 0              NaN                        NaN                   NaN
# 1              NaN                        NaN                   NaN
# 2              NaN                        NaN                   NaN
# 3              NaN                        NaN                   NaN
# 4              NaN                        NaN                   NaN

# %%
print(df.columns.tolist())
# Out:
# ['GameID', 'Team', 'Result', 'Game Time', 'Side', 'Patch', 'Tournament', 'Date', 'Region', 'Champion', 'Player', 'Role', 'Level', 'Kills', 'Deaths', 'Assists', 'KDA', 'CS', "CS in Team's Jungle", 'CS in Enemy Jungle', 'CSM', 'Golds', 'GPM', 'GOLD%', 'Vision Score', 'Wards placed', 'Wards destroyed', 'Control Wards Purchased', 'Detector Wards Placed', 'VSPM', 'WPM', 'VWPM', 'WCPM', 'VS%', 'Total damage to Champion', 'Physical Damage', 'Magic Damage', 'True Damage', 'DPM', 'DMG%', 'K+A Per Minute', 'KP%', 'Solo kills', 'Double kills', 'Triple kills', 'Quadra kills', 'Penta kills', 'GD@15', 'CSD@15', 'XPD@15', 'LVLD@15', 'Objectives Stolen', 'Damage dealt to turrets', 'Damage dealt to buildings', 'Total heal', 'Total Heals On Teammates', 'Damage self mitigated', 'Total Damage Shielded On Teammates', 'Time ccing others', 'Total Time CC Dealt', 'Total damage taken', 'Total Time Spent Dead', 'Consumables purchased', 'Items Purchased', 'Shutdown bounty collected', 'Shutdown bounty lost']

# %%
print(df.columns[[12, 18, 24, 25, 26, 27, 29, 47, 60]])
# Out:
# Index(['Level', 'CS in Team's Jungle', 'Vision Score', 'Wards placed',
#        'Wards destroyed', 'Control Wards Purchased', 'VSPM', 'GD@15',
#        'Total damage taken'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22990 entries, 0 to 22989
# Data columns (total 66 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GameID                              22990 non-null  int64
#  1   Team                                22990 non-null  object
#  2   Result                              22990 non-null  object
#  3   Game Time                           22990 non-null  object
#  4   Side                                22990 non-null  object
#  5   Patch                               22990 non-null  object
#  6   Tournament                          22990 non-null  object
#  7   Date                                22990 non-null  object
#  8   Region                              22990 non-null  object
#  9   Champion                            22990 non-null  object
#  10  Player                              22990 non-null  object
#  11  Role                                22990 non-null  object
#  12  Level                               22980 non-null  float64
#  13  Kills                               22990 non-null  int64
#  14  Deaths                              22990 non-null  int64
#  15  Assists                             22990 non-null  int64
#  16  KDA                                 22990 non-null  object
#  17  CS                                  22990 non-null  int64
#  18  CS in Team's Jungle                 22980 non-null  float64
#  19  CS in Enemy Jungle                  0 non-null      float64
#  20  CSM                                 22990 non-null  float64
#  21  Golds                               22990 non-null  int64
#  22  GPM                                 22990 non-null  int64
#  23  GOLD%                               22990 non-null  object
#  24  Vision Score                        22980 non-null  float64
#  25  Wards placed                        22980 non-null  float64
#  26  Wards destroyed                     22980 non-null  float64
#  27  Control Wards Purchased             22980 non-null  float64
#  28  Detector Wards Placed               14810 non-null  float64
#  29  VSPM                                22980 non-null  float64
#  30  WPM                                 22990 non-null  float64
#  31  VWPM                                22990 non-null  float64
#  32  WCPM                                22990 non-null  float64
#  33  VS%                                 22980 non-null  object
#  34  Total damage to Champion            22990 non-null  float64
#  35  Physical Damage                     22990 non-null  float64
#  36  Magic Damage                        22990 non-null  float64
#  37  True Damage                         22990 non-null  float64
#  38  DPM                                 22990 non-null  int64
#  39  DMG%                                22990 non-null  object
#  40  K+A Per Minute                      22990 non-null  float64
#  41  KP%                                 22990 non-null  object
#  42  Solo kills                          1727 non-null   float64
#  43  Double kills                        14810 non-null  float64
#  44  Triple kills                        14810 non-null  float64
#  45  Quadra kills                        14810 non-null  float64
#  46  Penta kills                         14810 non-null  float64
#  47  GD@15                               22980 non-null  float64
#  48  CSD@15                              14810 non-null  float64
#  49  XPD@15                              14810 non-null  float64
#  50  LVLD@15                             14810 non-null  float64
#  51  Objectives Stolen                   14810 non-null  float64
#  52  Damage dealt to turrets             14810 non-null  float64
#  53  Damage dealt to buildings           14810 non-null  float64
#  54  Total heal                          14810 non-null  float64
#  55  Total Heals On Teammates            14810 non-null  float64
#  56  Damage self mitigated               14810 non-null  float64
#  57  Total Damage Shielded On Teammates  14810 non-null  float64
#  58  Time ccing others                   14810 non-null  float64
#  59  Total Time CC Dealt                 14810 non-null  float64
#  60  Total damage taken                  22980 non-null  float64
#  61  Total Time Spent Dead               14810 non-null  float64
#  62  Consumables purchased               14810 non-null  float64
#  63  Items Purchased                     14810 non-null  float64
#  64  Shutdown bounty collected           14810 non-null  float64
#  65  Shutdown bounty lost                14810 non-null  float64
# dtypes: float64(42), int64(8), object(16)
# memory usage: 11.6+ MB

# %%
df = df[df["GameID"] != 63197]

# %%
df.isnull().sum()
# Out:
# GameID                          0
# Team                            0
# Result                          0
# Game Time                       0
# Side                            0
#                              ...
# Total Time Spent Dead        8170
# Consumables purchased        8170
# Items Purchased              8170
# Shutdown bounty collected    8170
# Shutdown bounty lost         8170
# Length: 66, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22980 entries, 0 to 22989
# Data columns (total 66 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GameID                              22980 non-null  int64
#  1   Team                                22980 non-null  object
#  2   Result                              22980 non-null  object
#  3   Game Time                           22980 non-null  object
#  4   Side                                22980 non-null  object
#  5   Patch                               22980 non-null  object
#  6   Tournament                          22980 non-null  object
#  7   Date                                22980 non-null  object
#  8   Region                              22980 non-null  object
#  9   Champion                            22980 non-null  object
#  10  Player                              22980 non-null  object
#  11  Role                                22980 non-null  object
#  12  Level                               22980 non-null  float64
#  13  Kills                               22980 non-null  int64
#  14  Deaths                              22980 non-null  int64
#  15  Assists                             22980 non-null  int64
#  16  KDA                                 22980 non-null  object
#  17  CS                                  22980 non-null  int64
#  18  CS in Team's Jungle                 22980 non-null  float64
#  19  CS in Enemy Jungle                  0 non-null      float64
#  20  CSM                                 22980 non-null  float64
#  21  Golds                               22980 non-null  int64
#  22  GPM                                 22980 non-null  int64
#  23  GOLD%                               22980 non-null  object
#  24  Vision Score                        22980 non-null  float64
#  25  Wards placed                        22980 non-null  float64
#  26  Wards destroyed                     22980 non-null  float64
#  27  Control Wards Purchased             22980 non-null  float64
#  28  Detector Wards Placed               14810 non-null  float64
#  29  VSPM                                22980 non-null  float64
#  30  WPM                                 22980 non-null  float64
#  31  VWPM                                22980 non-null  float64
#  32  WCPM                                22980 non-null  float64
#  33  VS%                                 22980 non-null  object
#  34  Total damage to Champion            22980 non-null  float64
#  35  Physical Damage                     22980 non-null  float64
#  36  Magic Damage                        22980 non-null  float64
#  37  True Damage                         22980 non-null  float64
#  38  DPM                                 22980 non-null  int64
#  39  DMG%                                22980 non-null  object
#  40  K+A Per Minute                      22980 non-null  float64
#  41  KP%                                 22980 non-null  object
#  42  Solo kills                          1727 non-null   float64
#  43  Double kills                        14810 non-null  float64
#  44  Triple kills                        14810 non-null  float64
#  45  Quadra kills                        14810 non-null  float64
#  46  Penta kills                         14810 non-null  float64
#  47  GD@15                               22980 non-null  float64
#  48  CSD@15                              14810 non-null  float64
#  49  XPD@15                              14810 non-null  float64
#  50  LVLD@15                             14810 non-null  float64
#  51  Objectives Stolen                   14810 non-null  float64
#  52  Damage dealt to turrets             14810 non-null  float64
#  53  Damage dealt to buildings           14810 non-null  float64
#  54  Total heal                          14810 non-null  float64
#  55  Total Heals On Teammates            14810 non-null  float64
#  56  Damage self mitigated               14810 non-null  float64
#  57  Total Damage Shielded On Teammates  14810 non-null  float64
#  58  Time ccing others                   14810 non-null  float64
#  59  Total Time CC Dealt                 14810 non-null  float64
#  60  Total damage taken                  22980 non-null  float64
#  61  Total Time Spent Dead               14810 non-null  float64
#  62  Consumables purchased               14810 non-null  float64
#  63  Items Purchased                     14810 non-null  float64
#  64  Shutdown bounty collected           14810 non-null  float64
#  65  Shutdown bounty lost                14810 non-null  float64
# dtypes: float64(42), int64(8), object(16)
# memory usage: 11.7+ MB

# %%
df = df.dropna(axis=1)

# %%
df.head()
# Out:
#    GameID          Team Result Game Time  Side  Patch        Tournament  \
# 0   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 1   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 2   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 3   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 4   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
#
#          Date Region Champion   Player     Role  Level  Kills  Deaths  \
# 0  2025-01-12     CN   Ksante  Breathe      TOP   18.0      4       0
# 1  2025-01-12     CN    Viego     Tian   JUNGLE   17.0      4       0
# 2  2025-01-12     CN   Aurora   xiaohu      MID   18.0      5       1
# 3  2025-01-12     CN     Ashe    Light      ADC   16.0      3       2
# 4  2025-01-12     CN    Braum     Hang  SUPPORT   14.0      1       2
#
#    Assists          KDA   CS  CS in Team's Jungle  CSM  Golds  GPM  GOLD%  \
# 0        3  Perfect KDA  314                  4.0  8.9  14706  416  21.2%
# 1        5  Perfect KDA  273                238.0  7.7  14586  412    21%
# 2        8           13  286                  4.0  8.1  15720  444  22.6%
# 3        6          4.5  305                 21.0  8.6  14688  415  21.1%
# 4       11            6   38                  0.0  1.1   9762  276  14.1%
#
#    Vision Score  Wards placed  Wards destroyed  Control Wards Purchased  VSPM  \
# 0         31.78          14.0              3.0                      5.0  0.90
# 1         54.74          13.0             14.0                     12.0  1.55
# 2         42.96          11.0             11.0                      7.0  1.21
# 3         57.29           9.0             17.0                      3.0  1.62
# 4        144.10          67.0             20.0                     19.0  4.07
#
#     WPM  VWPM  WCPM    VS%  Total damage to Champion  Physical Damage  \
# 0  0.40  0.14  0.08   9.6%                   9830.40          7914.28
# 1  0.37  0.34  0.40  16.5%                  10013.26          8758.59
# 2  0.31  0.20  0.31    13%                  37571.06          1077.96
# 3  0.25  0.08  0.48  17.3%                  15603.29         14094.30
# 4  1.89  0.54  0.57  43.6%                   6292.02           465.85
#
#    Magic Damage  True Damage   DPM   DMG%  K+A Per Minute    KP%   GD@15  \
# 0       1012.28       903.84   278  12.4%            0.20  41.2%  -600.0
# 1       1070.67       184.00   283  12.6%            0.25  52.9%   528.0
# 2      35183.30      1309.80  1062  47.4%            0.37  76.5%  1072.0
# 3       1508.99         0.00   441  19.7%            0.25  52.9%  -199.0
# 4       5826.17         0.00   178   7.9%            0.34  70.6%   250.0
#
#    Total damage taken
# 0             26434.7
# 1             42723.7
# 2             16880.7
# 3             15290.8
# 4             17962.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22980 entries, 0 to 22989
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   GameID                    22980 non-null  int64
#  1   Team                      22980 non-null  object
#  2   Result                    22980 non-null  object
#  3   Game Time                 22980 non-null  object
#  4   Side                      22980 non-null  object
#  5   Patch                     22980 non-null  object
#  6   Tournament                22980 non-null  object
#  7   Date                      22980 non-null  object
#  8   Region                    22980 non-null  object
#  9   Champion                  22980 non-null  object
#  10  Player                    22980 non-null  object
#  11  Role                      22980 non-null  object
#  12  Level                     22980 non-null  float64
#  13  Kills                     22980 non-null  int64
#  14  Deaths                    22980 non-null  int64
#  15  Assists                   22980 non-null  int64
#  16  KDA                       22980 non-null  object
#  17  CS                        22980 non-null  int64
#  18  CS in Team's Jungle       22980 non-null  float64
#  19  CSM                       22980 non-null  float64
#  20  Golds                     22980 non-null  int64
#  21  GPM                       22980 non-null  int64
#  22  GOLD%                     22980 non-null  object
#  23  Vision Score              22980 non-null  float64
#  24  Wards placed              22980 non-null  float64
#  25  Wards destroyed           22980 non-null  float64
#  26  Control Wards Purchased   22980 non-null  float64
#  27  VSPM                      22980 non-null  float64
#  28  WPM                       22980 non-null  float64
#  29  VWPM                      22980 non-null  float64
#  30  WCPM                      22980 non-null  float64
#  31  VS%                       22980 non-null  object
#  32  Total damage to Champion  22980 non-null  float64
#  33  Physical Damage           22980 non-null  float64
#  34  Magic Damage              22980 non-null  float64
#  35  True Damage               22980 non-null  float64
#  36  DPM                       22980 non-null  int64
#  37  DMG%                      22980 non-null  object
#  38  K+A Per Minute            22980 non-null  float64
#  39  KP%                       22980 non-null  object
#  40  GD@15                     22980 non-null  float64
#  41  Total damage taken        22980 non-null  float64
# dtypes: float64(18), int64(8), object(16)
# memory usage: 7.5+ MB

# %%
df = df.drop(["KDA","CS in Team's Jungle", "CSM", "Physical Damage", "Magic Damage", "True Damage", "Total damage taken", "Total damage to Champion", "CS", "Vision Score", "Wards placed", "Wards destroyed", "Control Wards Purchased", "VSPM", "WPM", "WCPM", "VWPM" ], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22980 entries, 0 to 22989
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GameID          22980 non-null  int64
#  1   Team            22980 non-null  object
#  2   Result          22980 non-null  object
#  3   Game Time       22980 non-null  object
#  4   Side            22980 non-null  object
#  5   Patch           22980 non-null  object
#  6   Tournament      22980 non-null  object
#  7   Date            22980 non-null  object
#  8   Region          22980 non-null  object
#  9   Champion        22980 non-null  object
#  10  Player          22980 non-null  object
#  11  Role            22980 non-null  object
#  12  Level           22980 non-null  float64
#  13  Kills           22980 non-null  int64
#  14  Deaths          22980 non-null  int64
#  15  Assists         22980 non-null  int64
#  16  Golds           22980 non-null  int64
#  17  GPM             22980 non-null  int64
#  18  GOLD%           22980 non-null  object
#  19  VS%             22980 non-null  object
#  20  DPM             22980 non-null  int64
#  21  DMG%            22980 non-null  object
#  22  K+A Per Minute  22980 non-null  float64
#  23  KP%             22980 non-null  object
#  24  GD@15           22980 non-null  float64
# dtypes: float64(3), int64(7), object(15)
# memory usage: 4.6+ MB

# %%
df["Result"] = df["Result"].map({"WIN": 1, "LOSS": 0})

# %%
df["Champion"] = df["Champion"].str.replace("rek", "reksai")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'champion'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 df["champion"] = df["champion"].str.replace("rek", "reksai")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'champion'

# %%
df["Patch"] = df["Patch"].str.lstrip("v")

# %%
df["Side"] = df["Side"].map({"Blue": 1, "Red":  0})

# %%
df["Game Time"] = pd.to_timedelta("00:" + df["Game Time"])
df["Game Time"] = pd.to_timedelta(df["Game Time"]).dt.total_seconds()

# %%
df["KP%"] = (df["KP%"].str.rstrip("%").astype(float)/100).round(3)
df["GOLD%"] = (df["GOLD%"].str.rstrip("%").astype(float)/100).round(3)
df["VS%"] = (df["VS%"].str.rstrip("%").astype(float)/100).round(3)
df["DMG%"] = (df["DMG%"].str.rstrip("%").astype(float)/100).round(3)

# %%
numerical_cols = df.select_dtypes(include=["number"]).columns
correlation_matrix = df[numerical_cols].corr()

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
correlation_matrix

# %%
df.hist(bins=50, figsize=(60,20))
# Out:
# array([[<Axes: title={'center': 'GameID'}>,
#         <Axes: title={'center': 'Result'}>,
#         <Axes: title={'center': 'Level'}>],
#        [<Axes: title={'center': 'Kills'}>,
#         <Axes: title={'center': 'Deaths'}>,
#         <Axes: title={'center': 'Assists'}>],
#        [<Axes: title={'center': 'Golds'}>,
#         <Axes: title={'center': 'GPM'}>, <Axes: title={'center': 'DPM'}>],
#        [<Axes: title={'center': 'K+A Per Minute'}>,
#         <Axes: title={'center': 'GD@15'}>, <Axes: >]], dtype=object)

# %%
df
# Out:
#        GameID          Team  Result Game Time  Side   Patch  \
# 0       62896  Weibo Gaming       1     35:23  Blue   v15.1
# 1       62896  Weibo Gaming       1     35:23  Blue   v15.1
# 2       62896  Weibo Gaming       1     35:23  Blue   v15.1
# 3       62896  Weibo Gaming       1     35:23  Blue   v15.1
# 4       62896  Weibo Gaming       1     35:23  Blue   v15.1
# ...       ...           ...     ...       ...   ...     ...
# 22985   72873     PSG Talon       0     27:22   Red  v15.20
# 22986   72873     PSG Talon       0     27:22   Red  v15.20
# 22987   72873     PSG Talon       0     27:22   Red  v15.20
# 22988   72873     PSG Talon       0     27:22   Red  v15.20
# 22989   72873     PSG Talon       0     27:22   Red  v15.20
#
#                    Tournament        Date Region Champion   Player     Role  \
# 0            LPL 2025 Split 1  2025-01-12     CN   Ksante  Breathe      TOP
# 1            LPL 2025 Split 1  2025-01-12     CN    Viego     Tian   JUNGLE
# 2            LPL 2025 Split 1  2025-01-12     CN   Aurora   xiaohu      MID
# 3            LPL 2025 Split 1  2025-01-12     CN     Ashe    Light      ADC
# 4            LPL 2025 Split 1  2025-01-12     CN    Braum     Hang  SUPPORT
# ...                       ...         ...    ...      ...      ...      ...
# 22985  Worlds 2025 Main Event  2025-10-15     WR   Rumble     Azhi      TOP
# 22986  Worlds 2025 Main Event  2025-10-15     WR       Vi    Karsa   JUNGLE
# 22987  Worlds 2025 Main Event  2025-10-15     WR    Swain    Maple      MID
# 22988  Worlds 2025 Main Event  2025-10-15     WR    Sivir    Betty      ADC
# 22989  Worlds 2025 Main Event  2025-10-15     WR     Rell    Woody  SUPPORT
#
#        Level  Kills  Deaths  Assists  Golds  GPM  GOLD%    VS%   DPM   DMG%  \
# 0       18.0      4       0        3  14706  416  21.2%   9.6%   278  12.4%
# 1       17.0      4       0        5  14586  412    21%  16.5%   283  12.6%
# 2       18.0      5       1        8  15720  444  22.6%    13%  1062  47.4%
# 3       16.0      3       2        6  14688  415  21.1%  17.3%   441  19.7%
# 4       14.0      1       2       11   9762  276  14.1%  43.6%   178   7.9%
# ...      ...    ...     ...      ...    ...  ...    ...    ...   ...    ...
# 22985   14.0      3       5        3   9957  364  22.1%  12.1%   607  26.5%
# 22986   14.0      4       3        1   9546  349  21.2%  19.8%   303  13.2%
# 22987   15.0      3       5        5  10619  388  23.6%  13.2%   653  28.5%
# 22988   14.0      0       3        3   8685  317  19.3%  10.4%   577  25.2%
# 22989   11.0      0       5        8   6265  229  13.9%  44.5%   152   6.6%
#
#        K+A Per Minute    KP%   GD@15
# 0                0.20  41.2%  -600.0
# 1                0.25  52.9%   528.0
# 2                0.37  76.5%  1072.0
# 3                0.25  52.9%  -199.0
# 4                0.34  70.6%   250.0
# ...               ...    ...     ...
# 22985            0.22    60%   344.0
# 22986            0.18    50%   238.0
# 22987            0.29    80%   210.0
# 22988            0.11    30% -1594.0
# 22989            0.29    80%  -298.0
#
# [22980 rows x 25 columns]

# %%
# fix team names for anyone's legend and psg talon has renamed themselves
df["Team"] = df["Team"].str.replace("anyone s legend", "Anyones Legend", case=False)
df['Team'] = df['Team'].str.replace('^talon$', 'PSG Talon', case=False, regex=True)

# %%
team_stats = df.groupby(["GameID", "Team"], as_index=False).agg({
    "Date": "first",
    "Region": "first",
    "Kills": "sum",
    "Deaths": "sum",
    "Assists": "sum",
    "Result": "first",
    "Game Time": "first",
    "Side": "first",
    "Patch": "first",
    "GD@15": "sum"
})

# %%
champions_per_role = df.groupby(["GameID", "Team", "Role"])["Champion"].first().unstack()
champions_per_role.columns = [f"{role}_champion" for role in champions_per_role.columns]

# %%
player_per_role = df.groupby(["GameID", "Team", "Role"])["Player"].first().unstack()
player_per_role.columns = [f"{role}_player" for role in player_per_role.columns]

# %%
kills_per_role = df.groupby(["GameID", "Team", "Role"])["Kills"].first().unstack()
kills_per_role.columns = [f"{role}_kills" for role in kills_per_role.columns]

# %%
assists_per_role = df.groupby(["GameID", "Team", "Role"])["Assists"].first().unstack()
assists_per_role.columns = [f"{role}_assists" for role in assists_per_role.columns]

# %%
deaths_per_role = df.groupby(["GameID", "Team", "Role"])["Deaths"].first().unstack()
deaths_per_role.columns = [f"{role}_deaths" for role in deaths_per_role.columns]

# %%
kp_per_role = df.groupby(["GameID", "Team", "Role"])["KP%"].first().unstack()
kp_per_role.columns = [f"{role}_kp%" for role in kp_per_role.columns]

# %%
dmg_per_role = df.groupby(["GameID", "Team", "Role"])["DMG%"].first().unstack()
dmg_per_role.columns = [f"{role}_dmg%" for role in dmg_per_role.columns]

# %%
ka_per_role = df.groupby(["GameID", "Team", "Role"])["K+A Per Minute"].first().unstack()
ka_per_role.columns = [f"{role}_ka_per_minute" for role in ka_per_role.columns]

# %%
gd_per_role = df.groupby(["GameID", "Team", "Role"])["GD@15"].first().unstack()
gd_per_role.columns = [f"{role}_gd@15" for role in gd_per_role.columns]

# %%
team_stats = (team_stats.merge(champions_per_role, on=["GameID", "Team"], how="left")
             .merge(player_per_role, on=["GameID", "Team"], how="left")
             .merge(kills_per_role, on=["GameID", "Team"], how="left")
             .merge(assists_per_role, on=["GameID", "Team"], how="left")
             .merge(deaths_per_role, on=["GameID", "Team"], how="left")
             .merge(kp_per_role, on=["GameID", "Team"], how="left")
             .merge(dmg_per_role, on=["GameID", "Team"], how="left")
             .merge(ka_per_role, on=["GameID", "Team"], how="left")
             .merge(gd_per_role, on=["GameID", "Team"], how="left")
             )

# %%
team_stats
# Out:
#       GameID                 Team        Date Region  Kills  Deaths  Assists  \
# 0      62896                  OMG  2025-01-12     CN      5      17        9
# 1      62896         Weibo Gaming  2025-01-12     CN     17       5       33
# 2      62897                  OMG  2025-01-12     CN     11      18       27
# 3      62897         Weibo Gaming  2025-01-12     CN     18      11       40
# 4      62898                  OMG  2025-01-12     CN     18      22       40
# ...      ...                  ...         ...    ...    ...     ...      ...
# 4591   72871  Hanwha Life eSports  2025-10-15     WR     14      29       35
# 4592   72872           G2 Esports  2025-10-15     WR      7      22       19
# 4593   72872          Top Esports  2025-10-15     WR     22       7       56
# 4594   72873        Gen.G eSports  2025-10-15     WR     21      10       48
# 4595   72873            PSG Talon  2025-10-15     WR     10      21       20
#
#       Result Game Time  Side   Patch   GD@15  ADC_champion JUNGLE_champion  \
# 0          0     35:23   Red   v15.1 -1051.0         Varus        Nocturne
# 1          1     35:23  Blue   v15.1  1051.0          Ashe           Viego
# 2          0     32:32  Blue   v15.1 -2888.0          Jhin          Maokai
# 3          1     32:32   Red   v15.1  2888.0  Miss Fortune          Wukong
# 4          0     33:34  Blue   v15.1  2460.0         Ziggs            Zyra
# ...      ...       ...   ...     ...     ...           ...             ...
# 4591       0     41:14  Blue  v15.20   259.0         Kaisa       Jarvan IV
# 4592       0     32:25  Blue  v15.20 -2517.0         Xayah        Xin Zhao
# 4593       1     32:25   Red  v15.20  2517.0        Yunara         Trundle
# 4594       1     27:22  Blue  v15.20  1100.0        Lucian          Wukong
# 4595       0     27:22   Red  v15.20 -1100.0         Sivir              Vi
#
#      MID_champion SUPPORT_champion TOP_champion  ADC_player JUNGLE_player  \
# 0         Orianna            Neeko         Gnar      Starry          Heng
# 1          Aurora            Braum       Ksante       Light          Tian
# 2         Ambessa             Rell       Rumble      Starry          Heng
# 3          Viktor            Rakan        Jayce       Light          Tian
# 4            Yone            Leona       Aatrox      Starry          Heng
# ...           ...              ...          ...         ...           ...
# 4591         Ryze          Alistar       Ksante       Viper        Peanut
# 4592         Azir            Rakan         Sion   Hans Sama      SkewMond
# 4593      Orianna            Karma       Aatrox  JackeyLove        Kanavi
# 4594        Galio            Braum      Ambessa       Ruler        Canyon
# 4595        Swain             Rell       Rumble       Betty         Karsa
#
#      MID_player SUPPORT_player   TOP_player  ADC_kills  JUNGLE_kills  \
# 0       Linfeng          Moham         Hery          2             2
# 1        xiaohu           Hang      Breathe          3             4
# 2       Linfeng          Moham         Hery          0             1
# 3        xiaohu           Hang      Breathe          4             6
# 4       Linfeng          Moham         Hery          5             6
# ...         ...            ...          ...        ...           ...
# 4591       Zeka        Delight         Zeus         11             0
# 4592       Caps         Labrov  Brokenblade          2             3
# 4593      Creme           Hang          369          7             9
# 4594      Chovy           Duro         Kiin          8             4
# 4595      Maple          Woody         Azhi          0             4
#
#       MID_kills  SUPPORT_kills  TOP_kills  ADC_assists  JUNGLE_assists  \
# 0             0              0          1            2               1
# 1             5              1          4            6               5
# 2             4              0          6            5               7
# 3             1              2          5            9               6
# 4             6              0          1            9               9
# ...         ...            ...        ...          ...             ...
# 4591          2              0          1            0              13
# 4592          1              1          0            5               4
# 4593          4              0          2           11               8
# 4594          7              0          2            9               6
# 4595          3              0          3            3               1
#
#       MID_assists  SUPPORT_assists  TOP_assists  ADC_deaths  JUNGLE_deaths  \
# 0               3                3            0           4              4
# 1               8               11            3           2              0
# 2               2                9            4           3              6
# 3               7               11            7           1              2
# 4               4               13            5           3              6
# ...           ...              ...          ...         ...            ...
# 4591            2               13            7           4              5
# 4592            3                6            1           3              5
# 4593           10               17           10           3              0
# 4594           10               16            7           1              2
# 4595            5                8            3           3              3
#
#       MID_deaths  SUPPORT_deaths  TOP_deaths ADC_kp% JUNGLE_kp% MID_kp%  \
# 0              3               4           2     80%        60%     60%
# 1              1               2           0   52.9%      52.9%   76.5%
# 2              4               4           1   45.5%      72.7%   54.5%
# 3              3               2           3   72.2%      66.7%   44.4%
# 4              6               3           4   77.8%      83.3%   55.6%
# ...          ...             ...         ...     ...        ...     ...
# 4591           6              10           4   78.6%      92.9%   28.6%
# 4592           5               4           5    100%       100%   57.1%
# 4593           1               2           1   81.8%      77.3%   63.6%
# 4594           1               2           4     81%      47.6%     81%
# 4595           5               5           5     30%        50%     80%
#
#      SUPPORT_kp% TOP_kp% ADC_dmg% JUNGLE_dmg% MID_dmg% SUPPORT_dmg% TOP_dmg%  \
# 0            60%     20%    21.3%       14.6%    23.1%        14.7%    26.2%
# 1          70.6%   41.2%    19.7%       12.6%    47.4%         7.9%    12.4%
# 2          81.8%   90.9%     9.7%       21.3%    24.3%         5.6%      39%
# 3          72.2%   66.7%    31.6%       15.7%    30.6%         4.4%    17.8%
# 4          72.2%   33.3%    31.4%       28.5%    16.6%         9.1%    14.4%
# ...          ...     ...      ...         ...      ...          ...      ...
# 4591       92.9%   57.1%    32.2%       13.5%    21.8%         6.5%    26.1%
# 4592        100%   14.3%    29.9%       20.8%    27.1%         7.1%    15.1%
# 4593       77.3%   54.5%      29%       18.3%    24.4%         7.4%    20.9%
# 4594       76.2%   42.9%    33.8%       10.6%      27%         7.3%    21.3%
# 4595         80%     60%    25.2%       13.2%    28.5%         6.6%    26.5%
#
#       ADC_ka_per_minute  JUNGLE_ka_per_minute  MID_ka_per_minute  \
# 0                  0.11                  0.08               0.08
# 1                  0.25                  0.25               0.37
# 2                  0.15                  0.25               0.18
# 3                  0.40                  0.37               0.25
# 4                  0.42                  0.45               0.30
# ...                 ...                   ...                ...
# 4591               0.27                  0.32               0.10
# 4592               0.22                  0.22               0.12
# 4593               0.56                  0.52               0.43
# 4594               0.62                  0.37               0.62
# 4595               0.11                  0.18               0.29
#
#       SUPPORT_ka_per_minute  TOP_ka_per_minute  ADC_gd@15  JUNGLE_gd@15  \
# 0                      0.08               0.03      199.0        -528.0
# 1                      0.34               0.20     -199.0         528.0
# 2                      0.28               0.31    -1727.0         197.0
# 3                      0.40               0.37     1727.0        -197.0
# 4                      0.39               0.18      672.0         936.0
# ...                     ...                ...        ...           ...
# 4591                   0.32               0.19      708.0        -626.0
# 4592                   0.22               0.03     -698.0       -1100.0
# 4593                   0.52               0.37      698.0        1100.0
# 4594                   0.58               0.33     1594.0        -238.0
# 4595                   0.29               0.22    -1594.0         238.0
#
#       MID_gd@15  SUPPORT_gd@15  TOP_gd@15
# 0       -1072.0         -250.0      600.0
# 1        1072.0          250.0     -600.0
# 2        -922.0         -245.0     -191.0
# 3         922.0          245.0      191.0
# 4         178.0         1077.0     -403.0
# ...         ...            ...        ...
# 4591      -46.0         -137.0      360.0
# 4592      344.0         -323.0     -740.0
# 4593     -344.0          323.0      740.0
# 4594     -210.0          298.0     -344.0
# 4595      210.0         -298.0      344.0
#
# [4596 rows x 57 columns]

# %%
team_stats['Patch'] = team_stats['Patch'].astype(str)
team_stats.to_csv("combined_team_match_history.csv", index=False)
