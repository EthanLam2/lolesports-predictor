# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#dtype warning for columns (12,18,24,25,26,27,29,47,60)
dtype_columns = {"Level":float, "CS in Team's Jungle":float, "Vision Score":float, "Wards placed":float, "Wards destroyed":float, "Control Wards Purchased":float, "VSPM":float, "GD@15":float, "Total damage taken":float}

# %%
# stops pandas from interpreting NA (the region) as missing value NaN
df = pd.read_csv("combined_match_stats.csv", keep_default_na=False,na_values=[""],low_memory=False)

# %%
df.head()
# Out:
#    GameID          Team Result Game Time  Side  Patch        Tournament  \
# 0   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 1   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 2   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 3   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 4   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
#
#          Date Region Champion  ... Damage self mitigated  \
# 0  2025-01-12     CN   Ksante  ...                   NaN
# 1  2025-01-12     CN    Viego  ...                   NaN
# 2  2025-01-12     CN   Aurora  ...                   NaN
# 3  2025-01-12     CN     Ashe  ...                   NaN
# 4  2025-01-12     CN    Braum  ...                   NaN
#
#   Total Damage Shielded On Teammates  Time ccing others  Total Time CC Dealt  \
# 0                                NaN                NaN                  NaN
# 1                                NaN                NaN                  NaN
# 2                                NaN                NaN                  NaN
# 3                                NaN                NaN                  NaN
# 4                                NaN                NaN                  NaN
#
#    Total damage taken  Total Time Spent Dead Consumables purchased  \
# 0             26434.7                    NaN                   NaN
# 1             42723.7                    NaN                   NaN
# 2             16880.7                    NaN                   NaN
# 3             15290.8                    NaN                   NaN
# 4             17962.1                    NaN                   NaN
#
#    Items Purchased  Shutdown bounty collected  Shutdown bounty lost
# 0              NaN                        NaN                   NaN
# 1              NaN                        NaN                   NaN
# 2              NaN                        NaN                   NaN
# 3              NaN                        NaN                   NaN
# 4              NaN                        NaN                   NaN
#
# [5 rows x 66 columns]

# %%
print(df.columns.tolist())
# Out:
# ['GameID', 'Team', 'Result', 'Game Time', 'Side', 'Patch', 'Tournament', 'Date', 'Region', 'Champion', 'Player', 'Role', 'Level', 'Kills', 'Deaths', 'Assists', 'KDA', 'CS', "CS in Team's Jungle", 'CS in Enemy Jungle', 'CSM', 'Golds', 'GPM', 'GOLD%', 'Vision Score', 'Wards placed', 'Wards destroyed', 'Control Wards Purchased', 'Detector Wards Placed', 'VSPM', 'WPM', 'VWPM', 'WCPM', 'VS%', 'Total damage to Champion', 'Physical Damage', 'Magic Damage', 'True Damage', 'DPM', 'DMG%', 'K+A Per Minute', 'KP%', 'Solo kills', 'Double kills', 'Triple kills', 'Quadra kills', 'Penta kills', 'GD@15', 'CSD@15', 'XPD@15', 'LVLD@15', 'Objectives Stolen', 'Damage dealt to turrets', 'Damage dealt to buildings', 'Total heal', 'Total Heals On Teammates', 'Damage self mitigated', 'Total Damage Shielded On Teammates', 'Time ccing others', 'Total Time CC Dealt', 'Total damage taken', 'Total Time Spent Dead', 'Consumables purchased', 'Items Purchased', 'Shutdown bounty collected', 'Shutdown bounty lost']

# %%
print(df.columns[[12, 18, 24, 25, 26, 27, 29, 47, 60]])
# Out:
# Index(['Level', 'CS in Team's Jungle', 'Vision Score', 'Wards placed',
#        'Wards destroyed', 'Control Wards Purchased', 'VSPM', 'GD@15',
#        'Total damage taken'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23160 entries, 0 to 23159
# Data columns (total 66 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GameID                              23160 non-null  int64
#  1   Team                                23160 non-null  object
#  2   Result                              23160 non-null  object
#  3   Game Time                           23160 non-null  object
#  4   Side                                23160 non-null  object
#  5   Patch                               23160 non-null  object
#  6   Tournament                          23160 non-null  object
#  7   Date                                23160 non-null  object
#  8   Region                              23160 non-null  object
#  9   Champion                            23160 non-null  object
#  10  Player                              23160 non-null  object
#  11  Role                                23160 non-null  object
#  12  Level                               23150 non-null  float64
#  13  Kills                               23160 non-null  int64
#  14  Deaths                              23160 non-null  int64
#  15  Assists                             23160 non-null  int64
#  16  KDA                                 23160 non-null  object
#  17  CS                                  23160 non-null  int64
#  18  CS in Team's Jungle                 23150 non-null  float64
#  19  CS in Enemy Jungle                  0 non-null      float64
#  20  CSM                                 23160 non-null  float64
#  21  Golds                               23160 non-null  int64
#  22  GPM                                 23160 non-null  int64
#  23  GOLD%                               23160 non-null  object
#  24  Vision Score                        23150 non-null  float64
#  25  Wards placed                        23150 non-null  float64
#  26  Wards destroyed                     23150 non-null  float64
#  27  Control Wards Purchased             23150 non-null  float64
#  28  Detector Wards Placed               14980 non-null  float64
#  29  VSPM                                23150 non-null  float64
#  30  WPM                                 23160 non-null  float64
#  31  VWPM                                23160 non-null  float64
#  32  WCPM                                23160 non-null  float64
#  33  VS%                                 23150 non-null  object
#  34  Total damage to Champion            23160 non-null  float64
#  35  Physical Damage                     23160 non-null  float64
#  36  Magic Damage                        23160 non-null  float64
#  37  True Damage                         23160 non-null  float64
#  38  DPM                                 23160 non-null  int64
#  39  DMG%                                23160 non-null  object
#  40  K+A Per Minute                      23160 non-null  float64
#  41  KP%                                 23160 non-null  object
#  42  Solo kills                          1744 non-null   float64
#  43  Double kills                        14980 non-null  float64
#  44  Triple kills                        14980 non-null  float64
#  45  Quadra kills                        14980 non-null  float64
#  46  Penta kills                         14980 non-null  float64
#  47  GD@15                               23150 non-null  float64
#  48  CSD@15                              14980 non-null  float64
#  49  XPD@15                              14980 non-null  float64
#  50  LVLD@15                             14980 non-null  float64
#  51  Objectives Stolen                   14980 non-null  float64
#  52  Damage dealt to turrets             14980 non-null  float64
#  53  Damage dealt to buildings           14980 non-null  float64
#  54  Total heal                          14980 non-null  float64
#  55  Total Heals On Teammates            14980 non-null  float64
#  56  Damage self mitigated               14980 non-null  float64
#  57  Total Damage Shielded On Teammates  14980 non-null  float64
#  58  Time ccing others                   14980 non-null  float64
#  59  Total Time CC Dealt                 14980 non-null  float64
#  60  Total damage taken                  23150 non-null  float64
#  61  Total Time Spent Dead               14980 non-null  float64
#  62  Consumables purchased               14980 non-null  float64
#  63  Items Purchased                     14980 non-null  float64
#  64  Shutdown bounty collected           14980 non-null  float64
#  65  Shutdown bounty lost                14980 non-null  float64
# dtypes: float64(42), int64(8), object(16)
# memory usage: 11.7+ MB

# %%
df = df[df["GameID"] != 63197]

# %%
df.isnull().sum()
# Out:
# GameID                          0
# Team                            0
# Result                          0
# Game Time                       0
# Side                            0
#                              ...
# Total Time Spent Dead        8170
# Consumables purchased        8170
# Items Purchased              8170
# Shutdown bounty collected    8170
# Shutdown bounty lost         8170
# Length: 66, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23150 entries, 0 to 23159
# Data columns (total 66 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GameID                              23150 non-null  int64
#  1   Team                                23150 non-null  object
#  2   Result                              23150 non-null  object
#  3   Game Time                           23150 non-null  object
#  4   Side                                23150 non-null  object
#  5   Patch                               23150 non-null  object
#  6   Tournament                          23150 non-null  object
#  7   Date                                23150 non-null  object
#  8   Region                              23150 non-null  object
#  9   Champion                            23150 non-null  object
#  10  Player                              23150 non-null  object
#  11  Role                                23150 non-null  object
#  12  Level                               23150 non-null  float64
#  13  Kills                               23150 non-null  int64
#  14  Deaths                              23150 non-null  int64
#  15  Assists                             23150 non-null  int64
#  16  KDA                                 23150 non-null  object
#  17  CS                                  23150 non-null  int64
#  18  CS in Team's Jungle                 23150 non-null  float64
#  19  CS in Enemy Jungle                  0 non-null      float64
#  20  CSM                                 23150 non-null  float64
#  21  Golds                               23150 non-null  int64
#  22  GPM                                 23150 non-null  int64
#  23  GOLD%                               23150 non-null  object
#  24  Vision Score                        23150 non-null  float64
#  25  Wards placed                        23150 non-null  float64
#  26  Wards destroyed                     23150 non-null  float64
#  27  Control Wards Purchased             23150 non-null  float64
#  28  Detector Wards Placed               14980 non-null  float64
#  29  VSPM                                23150 non-null  float64
#  30  WPM                                 23150 non-null  float64
#  31  VWPM                                23150 non-null  float64
#  32  WCPM                                23150 non-null  float64
#  33  VS%                                 23150 non-null  object
#  34  Total damage to Champion            23150 non-null  float64
#  35  Physical Damage                     23150 non-null  float64
#  36  Magic Damage                        23150 non-null  float64
#  37  True Damage                         23150 non-null  float64
#  38  DPM                                 23150 non-null  int64
#  39  DMG%                                23150 non-null  object
#  40  K+A Per Minute                      23150 non-null  float64
#  41  KP%                                 23150 non-null  object
#  42  Solo kills                          1744 non-null   float64
#  43  Double kills                        14980 non-null  float64
#  44  Triple kills                        14980 non-null  float64
#  45  Quadra kills                        14980 non-null  float64
#  46  Penta kills                         14980 non-null  float64
#  47  GD@15                               23150 non-null  float64
#  48  CSD@15                              14980 non-null  float64
#  49  XPD@15                              14980 non-null  float64
#  50  LVLD@15                             14980 non-null  float64
#  51  Objectives Stolen                   14980 non-null  float64
#  52  Damage dealt to turrets             14980 non-null  float64
#  53  Damage dealt to buildings           14980 non-null  float64
#  54  Total heal                          14980 non-null  float64
#  55  Total Heals On Teammates            14980 non-null  float64
#  56  Damage self mitigated               14980 non-null  float64
#  57  Total Damage Shielded On Teammates  14980 non-null  float64
#  58  Time ccing others                   14980 non-null  float64
#  59  Total Time CC Dealt                 14980 non-null  float64
#  60  Total damage taken                  23150 non-null  float64
#  61  Total Time Spent Dead               14980 non-null  float64
#  62  Consumables purchased               14980 non-null  float64
#  63  Items Purchased                     14980 non-null  float64
#  64  Shutdown bounty collected           14980 non-null  float64
#  65  Shutdown bounty lost                14980 non-null  float64
# dtypes: float64(42), int64(8), object(16)
# memory usage: 11.8+ MB

# %%
df = df.dropna(axis=1)

# %%
df.head()
# Out:
#    GameID          Team Result Game Time  Side  Patch        Tournament  \
# 0   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 1   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 2   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 3   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 4   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
#
#          Date Region Champion  ... Total damage to Champion Physical Damage  \
# 0  2025-01-12     CN   Ksante  ...                  9830.40         7914.28
# 1  2025-01-12     CN    Viego  ...                 10013.26         8758.59
# 2  2025-01-12     CN   Aurora  ...                 37571.06         1077.96
# 3  2025-01-12     CN     Ashe  ...                 15603.29        14094.30
# 4  2025-01-12     CN    Braum  ...                  6292.02          465.85
#
#    Magic Damage  True Damage   DPM   DMG% K+A Per Minute    KP%   GD@15  \
# 0       1012.28       903.84   278  12.4%           0.20  41.2%  -600.0
# 1       1070.67       184.00   283  12.6%           0.25  52.9%   528.0
# 2      35183.30      1309.80  1062  47.4%           0.37  76.5%  1072.0
# 3       1508.99         0.00   441  19.7%           0.25  52.9%  -199.0
# 4       5826.17         0.00   178   7.9%           0.34  70.6%   250.0
#
#    Total damage taken
# 0             26434.7
# 1             42723.7
# 2             16880.7
# 3             15290.8
# 4             17962.1
#
# [5 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23150 entries, 0 to 23159
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   GameID                    23150 non-null  int64
#  1   Team                      23150 non-null  object
#  2   Result                    23150 non-null  object
#  3   Game Time                 23150 non-null  object
#  4   Side                      23150 non-null  object
#  5   Patch                     23150 non-null  object
#  6   Tournament                23150 non-null  object
#  7   Date                      23150 non-null  object
#  8   Region                    23150 non-null  object
#  9   Champion                  23150 non-null  object
#  10  Player                    23150 non-null  object
#  11  Role                      23150 non-null  object
#  12  Level                     23150 non-null  float64
#  13  Kills                     23150 non-null  int64
#  14  Deaths                    23150 non-null  int64
#  15  Assists                   23150 non-null  int64
#  16  KDA                       23150 non-null  object
#  17  CS                        23150 non-null  int64
#  18  CS in Team's Jungle       23150 non-null  float64
#  19  CSM                       23150 non-null  float64
#  20  Golds                     23150 non-null  int64
#  21  GPM                       23150 non-null  int64
#  22  GOLD%                     23150 non-null  object
#  23  Vision Score              23150 non-null  float64
#  24  Wards placed              23150 non-null  float64
#  25  Wards destroyed           23150 non-null  float64
#  26  Control Wards Purchased   23150 non-null  float64
#  27  VSPM                      23150 non-null  float64
#  28  WPM                       23150 non-null  float64
#  29  VWPM                      23150 non-null  float64
#  30  WCPM                      23150 non-null  float64
#  31  VS%                       23150 non-null  object
#  32  Total damage to Champion  23150 non-null  float64
#  33  Physical Damage           23150 non-null  float64
#  34  Magic Damage              23150 non-null  float64
#  35  True Damage               23150 non-null  float64
#  36  DPM                       23150 non-null  int64
#  37  DMG%                      23150 non-null  object
#  38  K+A Per Minute            23150 non-null  float64
#  39  KP%                       23150 non-null  object
#  40  GD@15                     23150 non-null  float64
#  41  Total damage taken        23150 non-null  float64
# dtypes: float64(18), int64(8), object(16)
# memory usage: 7.6+ MB

# %%
df = df.drop(["KDA","CS in Team's Jungle", "CSM", "Physical Damage", "Magic Damage", "True Damage", "Total damage taken", "Total damage to Champion", "CS", "Vision Score", "Wards placed", "Wards destroyed", "Control Wards Purchased", "VSPM", "WPM", "WCPM", "VWPM" ], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23150 entries, 0 to 23159
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GameID          23150 non-null  int64
#  1   Team            23150 non-null  object
#  2   Result          23150 non-null  object
#  3   Game Time       23150 non-null  object
#  4   Side            23150 non-null  object
#  5   Patch           23150 non-null  object
#  6   Tournament      23150 non-null  object
#  7   Date            23150 non-null  object
#  8   Region          23150 non-null  object
#  9   Champion        23150 non-null  object
#  10  Player          23150 non-null  object
#  11  Role            23150 non-null  object
#  12  Level           23150 non-null  float64
#  13  Kills           23150 non-null  int64
#  14  Deaths          23150 non-null  int64
#  15  Assists         23150 non-null  int64
#  16  Golds           23150 non-null  int64
#  17  GPM             23150 non-null  int64
#  18  GOLD%           23150 non-null  object
#  19  VS%             23150 non-null  object
#  20  DPM             23150 non-null  int64
#  21  DMG%            23150 non-null  object
#  22  K+A Per Minute  23150 non-null  float64
#  23  KP%             23150 non-null  object
#  24  GD@15           23150 non-null  float64
# dtypes: float64(3), int64(7), object(15)
# memory usage: 4.6+ MB

# %%
df["Result"] = df["Result"].map({"WIN": 1, "LOSS": 0})

# %%
df["Champion"] = df["Champion"].str.replace(r"\bRek\b", "Reksai", regex=True)
df["Champion"] = df["Champion"].str.replace(r"\bKha\b", "Khazix", regex=True)

# %%
df["Patch"] = df["Patch"].str.lstrip("v")

# %%
df["Side"] = df["Side"].map({"Blue": 1, "Red":  0})

# %%
df["Game Time"] = pd.to_timedelta("00:" + df["Game Time"])
df["Game Time"] = pd.to_timedelta(df["Game Time"]).dt.total_seconds()

# %%
df["KP%"] = (df["KP%"].str.rstrip("%").astype(float)/100).round(3)
df["GOLD%"] = (df["GOLD%"].str.rstrip("%").astype(float)/100).round(3)
df["VS%"] = (df["VS%"].str.rstrip("%").astype(float)/100).round(3)
df["DMG%"] = (df["DMG%"].str.rstrip("%").astype(float)/100).round(3)

# %%
numerical_cols = df.select_dtypes(include=["number"]).columns
correlation_matrix = df[numerical_cols].corr()

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
correlation_matrix
# Out:
#                       GameID        Result     Game Time          Side  \
# GameID          1.000000e+00 -2.841263e-15 -1.687315e-02 -2.899481e-16
# Result         -2.841263e-15  1.000000e+00  3.172647e-17  5.841627e-02
# Game Time      -1.687315e-02  3.172647e-17  1.000000e+00 -2.576108e-17
# Side           -2.899481e-16  5.841627e-02 -2.576108e-17  1.000000e+00
# Level           2.402999e-02  3.150483e-01  4.888237e-01  1.716062e-02
# Kills           1.492723e-02  3.912431e-01  1.207767e-01  2.003167e-02
# Deaths          2.057605e-02 -5.447108e-01  1.683240e-01 -2.770015e-02
# Assists         4.640590e-02  5.861925e-01  2.044693e-01  2.976115e-02
# Golds           6.750389e-03  3.112711e-01  5.693988e-01  2.073432e-02
# GPM             2.054770e-02  3.992804e-01 -8.759432e-03  2.801604e-02
# GOLD%          -1.878010e-05 -2.198704e-05 -3.446209e-05 -5.276889e-05
# VS%            -2.228491e-05  1.469116e-05 -3.122435e-06  3.117393e-05
# DPM             2.340208e-02  2.210568e-01  1.024000e-01  2.326284e-02
# DMG%            1.922170e-05  3.868693e-05  5.196552e-06 -2.031064e-05
# K+A Per Minute  5.236019e-02  6.934937e-01 -4.611706e-02  3.705742e-02
# KP%             3.896040e-02  1.131233e-01  8.309882e-02  9.317361e-03
# GD@15           1.599174e-17  2.960012e-01 -2.233870e-18  4.440780e-02
#
#                    Level     Kills    Deaths   Assists     Golds       GPM  \
# GameID          0.024030  0.014927  0.020576  0.046406  0.006750  0.020548
# Result          0.315048  0.391243 -0.544711  0.586193  0.311271  0.399280
# Game Time       0.488824  0.120777  0.168324  0.204469  0.569399 -0.008759
# Side            0.017161  0.020032 -0.027700  0.029761  0.020734  0.028016
# Level           1.000000  0.492212 -0.285350  0.091831  0.859990  0.721521
# Kills           0.492212  1.000000 -0.274685  0.100781  0.687892  0.758452
# Deaths         -0.285350 -0.274685  1.000000 -0.173517 -0.251221 -0.436461
# Assists         0.091831  0.100781 -0.173517  1.000000  0.085439 -0.017492
# Golds           0.859990  0.687892 -0.251221  0.085439  1.000000  0.807003
# GPM             0.721521  0.758452 -0.436461 -0.017492  0.807003  1.000000
# GOLD%           0.642497  0.598231 -0.246665 -0.343032  0.730177  0.883701
# VS%            -0.689802 -0.366325  0.160433  0.318425 -0.579492 -0.707243
# DPM             0.611908  0.658289 -0.223686  0.000212  0.697255  0.774220
# DMG%            0.548961  0.500440 -0.202349 -0.270333  0.602865  0.726885
# K+A Per Minute  0.187239  0.534047 -0.345516  0.838411  0.249040  0.363530
# KP%            -0.048912  0.201784 -0.087152  0.416920  0.071333  0.030734
# GD@15           0.144139  0.341587 -0.290148  0.184017  0.215870  0.286146
#
#                    GOLD%       VS%       DPM      DMG%  K+A Per Minute  \
# GameID         -0.000019 -0.000022  0.023402  0.000019        0.052360
# Result         -0.000022  0.000015  0.221057  0.000039        0.693494
# Game Time      -0.000034 -0.000003  0.102400  0.000005       -0.046117
# Side           -0.000053  0.000031  0.023263 -0.000020        0.037057
# Level           0.642497 -0.689802  0.611908  0.548961        0.187239
# Kills           0.598231 -0.366325  0.658289  0.500440        0.534047
# Deaths         -0.246665  0.160433 -0.223686 -0.202349       -0.345516
# Assists        -0.343032  0.318425  0.000212 -0.270333        0.838411
# Golds           0.730177 -0.579492  0.697255  0.602865        0.249040
# GPM             0.883701 -0.707243  0.774220  0.726885        0.363530
# GOLD%           1.000000 -0.803456  0.730848  0.822272       -0.004346
# VS%            -0.803456  1.000000 -0.613346 -0.694456        0.093676
# DPM             0.730848 -0.613346  1.000000  0.878383        0.289383
# DMG%            0.822272 -0.694456  0.878383  1.000000        0.009295
# K+A Per Minute -0.004346  0.093676  0.289383  0.009295        1.000000
# KP%            -0.014299  0.200321  0.057622  0.012738        0.425445
# GD@15           0.132530  0.018667  0.203699  0.114683        0.341537
#
#                      KP%         GD@15
# GameID          0.038960  1.599174e-17
# Result          0.113123  2.960012e-01
# Game Time       0.083099 -2.233870e-18
# Side            0.009317  4.440780e-02
# Level          -0.048912  1.441388e-01
# Kills           0.201784  3.415874e-01
# Deaths         -0.087152 -2.901485e-01
# Assists         0.416920  1.840167e-01
# Golds           0.071333  2.158697e-01
# GPM             0.030734  2.861459e-01
# GOLD%          -0.014299  1.325300e-01
# VS%             0.200321  1.866650e-02
# DPM             0.057622  2.036985e-01
# DMG%            0.012738  1.146834e-01
# K+A Per Minute  0.425445  3.415370e-01
# KP%             1.000000  1.498379e-01
# GD@15           0.149838  1.000000e+00

# %%
df.hist(bins=50, figsize=(60,20))
# Out:
# array([[<Axes: title={'center': 'GameID'}>,
#         <Axes: title={'center': 'Result'}>,
#         <Axes: title={'center': 'Game Time'}>,
#         <Axes: title={'center': 'Side'}>],
#        [<Axes: title={'center': 'Level'}>,
#         <Axes: title={'center': 'Kills'}>,
#         <Axes: title={'center': 'Deaths'}>,
#         <Axes: title={'center': 'Assists'}>],
#        [<Axes: title={'center': 'Golds'}>,
#         <Axes: title={'center': 'GPM'}>,
#         <Axes: title={'center': 'GOLD%'}>,
#         <Axes: title={'center': 'VS%'}>],
#        [<Axes: title={'center': 'DPM'}>,
#         <Axes: title={'center': 'DMG%'}>,
#         <Axes: title={'center': 'K+A Per Minute'}>,
#         <Axes: title={'center': 'KP%'}>],
#        [<Axes: title={'center': 'GD@15'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df
# Out:
#        GameID          Team  Result  Game Time  Side  Patch  \
# 0       62896  Weibo Gaming       1     2123.0     1   15.1
# 1       62896  Weibo Gaming       1     2123.0     1   15.1
# 2       62896  Weibo Gaming       1     2123.0     1   15.1
# 3       62896  Weibo Gaming       1     2123.0     1   15.1
# 4       62896  Weibo Gaming       1     2123.0     1   15.1
# ...       ...           ...     ...        ...   ...    ...
# 23115   72886    KT Rolster       1     1760.0     0  15.20
# 23116   72886    KT Rolster       1     1760.0     0  15.20
# 23117   72886    KT Rolster       1     1760.0     0  15.20
# 23118   72886    KT Rolster       1     1760.0     0  15.20
# 23119   72886    KT Rolster       1     1760.0     0  15.20
#
#                    Tournament        Date Region    Champion   Player  \
# 0            LPL 2025 Split 1  2025-01-12     CN      Ksante  Breathe
# 1            LPL 2025 Split 1  2025-01-12     CN       Viego     Tian
# 2            LPL 2025 Split 1  2025-01-12     CN      Aurora   xiaohu
# 3            LPL 2025 Split 1  2025-01-12     CN        Ashe    Light
# 4            LPL 2025 Split 1  2025-01-12     CN       Braum     Hang
# ...                       ...         ...    ...         ...      ...
# 23115  Worlds 2025 Main Event  2025-10-17     WR    Renekton  PerfecT
# 23116  Worlds 2025 Main Event  2025-10-17     WR     Trundle     Cuzz
# 23117  Worlds 2025 Main Event  2025-10-17     WR  Cassiopeia      Bdd
# 23118  Worlds 2025 Main Event  2025-10-17     WR      Ezreal  deokdam
# 23119  Worlds 2025 Main Event  2025-10-17     WR     Alistar    Peter
#
#           Role  Level  Kills  Deaths  Assists  Golds  GPM  GOLD%    VS%   DPM  \
# 0          TOP   18.0      4       0        3  14706  416  0.212  0.096   278
# 1       JUNGLE   17.0      4       0        5  14586  412  0.210  0.165   283
# 2          MID   18.0      5       1        8  15720  444  0.226  0.130  1062
# 3          ADC   16.0      3       2        6  14688  415  0.211  0.173   441
# 4      SUPPORT   14.0      1       2       11   9762  276  0.141  0.436   178
# ...        ...    ...    ...     ...      ...    ...  ...    ...    ...   ...
# 23115      TOP   17.0      0       2        6  11581  395  0.194  0.155   556
# 23116   JUNGLE   16.0      3       0       14  12452  425  0.209  0.258   464
# 23117      MID   17.0      5       1       11  12942  441  0.217  0.107   860
# 23118      ADC   16.0      7       2        8  14070  480  0.236  0.103   868
# 23119  SUPPORT   12.0      3       2       11   8592  293  0.144  0.376   192
#
#         DMG%  K+A Per Minute    KP%   GD@15
# 0      0.124            0.20  0.412  -600.0
# 1      0.126            0.25  0.529   528.0
# 2      0.474            0.37  0.765  1072.0
# 3      0.197            0.25  0.529  -199.0
# 4      0.079            0.34  0.706   250.0
# ...      ...             ...    ...     ...
# 23115  0.189            0.20  0.333   428.0
# 23116  0.158            0.58  0.944   154.0
# 23117  0.292            0.55  0.889   351.0
# 23118  0.295            0.51  0.833   283.0
# 23119  0.065            0.48  0.778  -173.0
#
# [23110 rows x 25 columns]

# %%
# fix team names for anyone's legend and psg talon has renamed themselves
df["Team"] = df["Team"].str.replace("anyone s legend", "Anyones Legend", case=False)
df['Team'] = df['Team'].str.replace('^talon$', 'PSG Talon', case=False, regex=True)

# %%
team_stats = df.groupby(["GameID", "Team"], as_index=False).agg({
    "Date": "first",
    "Region": "first",
    "Kills": "sum",
    "Deaths": "sum",
    "Assists": "sum",
    "Result": "first",
    "Game Time": "first",
    "Side": "first",
    "Patch": "first",
    "GD@15": "sum"
})

# %%
champions_per_role = df.groupby(["GameID", "Team", "Role"])["Champion"].first().unstack()
champions_per_role.columns = [f"{role}_champion" for role in champions_per_role.columns]

# %%
player_per_role = df.groupby(["GameID", "Team", "Role"])["Player"].first().unstack()
player_per_role.columns = [f"{role}_player" for role in player_per_role.columns]

# %%
kills_per_role = df.groupby(["GameID", "Team", "Role"])["Kills"].first().unstack()
kills_per_role.columns = [f"{role}_kills" for role in kills_per_role.columns]

# %%
assists_per_role = df.groupby(["GameID", "Team", "Role"])["Assists"].first().unstack()
assists_per_role.columns = [f"{role}_assists" for role in assists_per_role.columns]

# %%
deaths_per_role = df.groupby(["GameID", "Team", "Role"])["Deaths"].first().unstack()
deaths_per_role.columns = [f"{role}_deaths" for role in deaths_per_role.columns]

# %%
kp_per_role = df.groupby(["GameID", "Team", "Role"])["KP%"].first().unstack()
kp_per_role.columns = [f"{role}_kp%" for role in kp_per_role.columns]

# %%
dmg_per_role = df.groupby(["GameID", "Team", "Role"])["DMG%"].first().unstack()
dmg_per_role.columns = [f"{role}_dmg%" for role in dmg_per_role.columns]

# %%
ka_per_role = df.groupby(["GameID", "Team", "Role"])["K+A Per Minute"].first().unstack()
ka_per_role.columns = [f"{role}_ka_per_minute" for role in ka_per_role.columns]

# %%
gd_per_role = df.groupby(["GameID", "Team", "Role"])["GD@15"].first().unstack()
gd_per_role.columns = [f"{role}_gd@15" for role in gd_per_role.columns]

# %%
team_stats = (team_stats.merge(champions_per_role, on=["GameID", "Team"], how="left")
             .merge(player_per_role, on=["GameID", "Team"], how="left")
             .merge(kills_per_role, on=["GameID", "Team"], how="left")
             .merge(assists_per_role, on=["GameID", "Team"], how="left")
             .merge(deaths_per_role, on=["GameID", "Team"], how="left")
             .merge(kp_per_role, on=["GameID", "Team"], how="left")
             .merge(dmg_per_role, on=["GameID", "Team"], how="left")
             .merge(ka_per_role, on=["GameID", "Team"], how="left")
             .merge(gd_per_role, on=["GameID", "Team"], how="left")
             )

# %%
team_stats
# Out:
#       GameID                Team        Date Region  Kills  Deaths  Assists  \
# 0      62896                 OMG  2025-01-12     CN      5      17        9
# 1      62896        Weibo Gaming  2025-01-12     CN     17       5       33
# 2      62897                 OMG  2025-01-12     CN     11      18       27
# 3      62897        Weibo Gaming  2025-01-12     CN     18      11       40
# 4      62898                 OMG  2025-01-12     CN     18      22       40
# ...      ...                 ...         ...    ...    ...     ...      ...
# 4617   72884  CTBC Flying Oyster  2025-10-17     WR      7      15       23
# 4618   72885          KT Rolster  2025-10-17     WR     28      10       69
# 4619   72885         Top Esports  2025-10-17     WR     10      28       20
# 4620   72886          KT Rolster  2025-10-17     WR     18       7       50
# 4621   72886         Top Esports  2025-10-17     WR      7      18       13
#
#       Result  Game Time  Side  Patch   GD@15  ADC_champion JUNGLE_champion  \
# 0          0     2123.0     0   15.1 -1051.0         Varus        Nocturne
# 1          1     2123.0     1   15.1  1051.0          Ashe           Viego
# 2          0     1952.0     1   15.1 -2888.0          Jhin          Maokai
# 3          1     1952.0     0   15.1  2888.0  Miss Fortune          Wukong
# 4          0     2014.0     1   15.1  2460.0         Ziggs            Zyra
# ...      ...        ...   ...    ...     ...           ...             ...
# 4617       0     1791.0     1  15.20   970.0  Miss Fortune              Vi
# 4618       1     1979.0     1  15.20 -1831.0         Corki          Wukong
# 4619       0     1979.0     0  15.20  1831.0         Kaisa       Jarvan IV
# 4620       1     1760.0     0  15.20  1043.0        Ezreal         Trundle
# 4621       0     1760.0     1  15.20 -1043.0         Xayah             Zed
#
#      MID_champion SUPPORT_champion TOP_champion  ADC_player JUNGLE_player  \
# 0         Orianna            Neeko         Gnar      Starry          Heng
# 1          Aurora            Braum       Ksante       Light          Tian
# 2         Ambessa             Rell       Rumble      Starry          Heng
# 3          Viktor            Rakan        Jayce       Light          Tian
# 4            Yone            Leona       Aatrox      Starry          Heng
# ...           ...              ...          ...         ...           ...
# 4617      Taliyah         Nautilus     Renekton       Doggo        JunJia
# 4618       Aurora         Nautilus       Rumble     deokdam          Cuzz
# 4619        Annie            Neeko      Ambessa  JackeyLove        Kanavi
# 4620   Cassiopeia          Alistar     Renekton     deokdam          Cuzz
# 4621         Ryze            Rakan       Ksante  JackeyLove        Kanavi
#
#      MID_player SUPPORT_player TOP_player  ADC_kills  JUNGLE_kills  MID_kills  \
# 0       Linfeng          Moham       Hery          2             2          0
# 1        xiaohu           Hang    Breathe          3             4          5
# 2       Linfeng          Moham       Hery          0             1          4
# 3        xiaohu           Hang    Breathe          4             6          1
# 4       Linfeng          Moham       Hery          5             6          6
# ...         ...            ...        ...        ...           ...        ...
# 4617      HongQ        Kaiwing       Rest          1             3          1
# 4618        Bdd          Peter    PerfecT          9             7          5
# 4619      Creme           Hang        369          4             1          2
# 4620        Bdd          Peter    PerfecT          7             3          5
# 4621      Creme           Hang        369          1             2          3
#
#       SUPPORT_kills  TOP_kills  ADC_assists  JUNGLE_assists  MID_assists  \
# 0                 0          1            2               1            3
# 1                 1          4            6               5            8
# 2                 0          6            5               7            2
# 3                 2          5            9               6            7
# 4                 0          1            9               9            4
# ...             ...        ...          ...             ...          ...
# 4617              0          2            5               3            6
# 4618              2          5           11              13           15
# 4619              0          3            2               7            3
# 4620              3          0            8              14           11
# 4621              1          0            2               4            3
#
#       SUPPORT_assists  TOP_assists  ADC_deaths  JUNGLE_deaths  MID_deaths  \
# 0                   3            0           4              4           3
# 1                  11            3           2              0           1
# 2                   9            4           3              6           4
# 3                  11            7           1              2           3
# 4                  13            5           3              6           6
# ...               ...          ...         ...            ...         ...
# 4617                6            3           3              4           3
# 4618               16           14           1              3           2
# 4619                4            4           5              6           7
# 4620               11            6           2              0           1
# 4621                3            1           3              3           4
#
#       SUPPORT_deaths  TOP_deaths  ADC_kp%  JUNGLE_kp%  MID_kp%  SUPPORT_kp%  \
# 0                  4           2    0.800       0.600    0.600        0.600
# 1                  2           0    0.529       0.529    0.765        0.706
# 2                  4           1    0.455       0.727    0.545        0.818
# 3                  2           3    0.722       0.667    0.444        0.722
# 4                  3           4    0.778       0.833    0.556        0.722
# ...              ...         ...      ...         ...      ...          ...
# 4617               3           2    0.857       0.857    1.000        0.857
# 4618               3           1    0.714       0.714    0.714        0.643
# 4619               7           3    0.600       0.800    0.500        0.400
# 4620               2           2    0.833       0.944    0.889        0.778
# 4621               4           4    0.429       0.857    0.857        0.571
#
#       TOP_kp%  ADC_dmg%  JUNGLE_dmg%  MID_dmg%  SUPPORT_dmg%  TOP_dmg%  \
# 0       0.200     0.213        0.146     0.231         0.147     0.262
# 1       0.412     0.197        0.126     0.474         0.079     0.124
# 2       0.909     0.097        0.213     0.243         0.056     0.390
# 3       0.667     0.316        0.157     0.306         0.044     0.178
# 4       0.333     0.314        0.285     0.166         0.091     0.144
# ...       ...       ...          ...       ...           ...       ...
# 4617    0.714     0.295        0.106     0.300         0.061     0.238
# 4618    0.679     0.257        0.215     0.238         0.066     0.223
# 4619    0.700     0.267        0.085     0.278         0.102     0.267
# 4620    0.333     0.295        0.158     0.292         0.065     0.189
# 4621    0.143     0.239        0.223     0.280         0.076     0.183
#
#       ADC_ka_per_minute  JUNGLE_ka_per_minute  MID_ka_per_minute  \
# 0                  0.11                  0.08               0.08
# 1                  0.25                  0.25               0.37
# 2                  0.15                  0.25               0.18
# 3                  0.40                  0.37               0.25
# 4                  0.42                  0.45               0.30
# ...                 ...                   ...                ...
# 4617               0.20                  0.20               0.23
# 4618               0.61                  0.61               0.61
# 4619               0.18                  0.24               0.15
# 4620               0.51                  0.58               0.55
# 4621               0.10                  0.20               0.20
#
#       SUPPORT_ka_per_minute  TOP_ka_per_minute  ADC_gd@15  JUNGLE_gd@15  \
# 0                      0.08               0.03      199.0        -528.0
# 1                      0.34               0.20     -199.0         528.0
# 2                      0.28               0.31    -1727.0         197.0
# 3                      0.40               0.37     1727.0        -197.0
# 4                      0.39               0.18      672.0         936.0
# ...                     ...                ...        ...           ...
# 4617                   0.20               0.17      979.0        -155.0
# 4618                   0.55               0.58     -300.0        -246.0
# 4619                   0.12               0.21      300.0         246.0
# 4620                   0.48               0.20      283.0         154.0
# 4621                   0.14               0.03     -283.0        -154.0
#
#       MID_gd@15  SUPPORT_gd@15  TOP_gd@15
# 0       -1072.0         -250.0      600.0
# 1        1072.0          250.0     -600.0
# 2        -922.0         -245.0     -191.0
# 3         922.0          245.0      191.0
# 4         178.0         1077.0     -403.0
# ...         ...            ...        ...
# 4617     -473.0          127.0      492.0
# 4618     -593.0         -249.0     -443.0
# 4619      593.0          249.0      443.0
# 4620      351.0         -173.0      428.0
# 4621     -351.0          173.0     -428.0
#
# [4622 rows x 57 columns]

# %%
team_stats['Patch'] = team_stats['Patch'].astype(str)
team_stats.to_csv("combined_team_match_history.csv", index=False)
