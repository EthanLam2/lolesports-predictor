# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#dtype warning for columns (12,18,24,25,26,27,29,47,60)
dtype_columns = {"Level":float, "CS in Team's Jungle":float, "Vision Score":float, "Wards placed":float, "Wards destroyed":float, "Control Wards Purchased":float, "VSPM":float, "GD@15":float, "Total damage taken":float}

# %%
# stops pandas from interpreting NA (the region) as missing value NaN
df = pd.read_csv("combined_match_stats.csv", keep_default_na=False,na_values=[""],low_memory=False)

# %%
df.head()
# Out:
#    GameID          Team Result Game Time  Side  Patch        Tournament  \
# 0   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 1   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 2   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 3   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 4   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
#
#          Date Region Champion  ... Damage self mitigated  \
# 0  2025-01-12     CN   Ksante  ...                   NaN
# 1  2025-01-12     CN    Viego  ...                   NaN
# 2  2025-01-12     CN   Aurora  ...                   NaN
# 3  2025-01-12     CN     Ashe  ...                   NaN
# 4  2025-01-12     CN    Braum  ...                   NaN
#
#   Total Damage Shielded On Teammates  Time ccing others  Total Time CC Dealt  \
# 0                                NaN                NaN                  NaN
# 1                                NaN                NaN                  NaN
# 2                                NaN                NaN                  NaN
# 3                                NaN                NaN                  NaN
# 4                                NaN                NaN                  NaN
#
#    Total damage taken  Total Time Spent Dead Consumables purchased  \
# 0             26434.7                    NaN                   NaN
# 1             42723.7                    NaN                   NaN
# 2             16880.7                    NaN                   NaN
# 3             15290.8                    NaN                   NaN
# 4             17962.1                    NaN                   NaN
#
#    Items Purchased  Shutdown bounty collected  Shutdown bounty lost
# 0              NaN                        NaN                   NaN
# 1              NaN                        NaN                   NaN
# 2              NaN                        NaN                   NaN
# 3              NaN                        NaN                   NaN
# 4              NaN                        NaN                   NaN
#
# [5 rows x 66 columns]

# %%
print(df.columns.tolist())
# Out:
# ['GameID', 'Team', 'Result', 'Game Time', 'Side', 'Patch', 'Tournament', 'Date', 'Region', 'Champion', 'Player', 'Role', 'Level', 'Kills', 'Deaths', 'Assists', 'KDA', 'CS', "CS in Team's Jungle", 'CS in Enemy Jungle', 'CSM', 'Golds', 'GPM', 'GOLD%', 'Vision Score', 'Wards placed', 'Wards destroyed', 'Control Wards Purchased', 'Detector Wards Placed', 'VSPM', 'WPM', 'VWPM', 'WCPM', 'VS%', 'Total damage to Champion', 'Physical Damage', 'Magic Damage', 'True Damage', 'DPM', 'DMG%', 'K+A Per Minute', 'KP%', 'Solo kills', 'Double kills', 'Triple kills', 'Quadra kills', 'Penta kills', 'GD@15', 'CSD@15', 'XPD@15', 'LVLD@15', 'Objectives Stolen', 'Damage dealt to turrets', 'Damage dealt to buildings', 'Total heal', 'Total Heals On Teammates', 'Damage self mitigated', 'Total Damage Shielded On Teammates', 'Time ccing others', 'Total Time CC Dealt', 'Total damage taken', 'Total Time Spent Dead', 'Consumables purchased', 'Items Purchased', 'Shutdown bounty collected', 'Shutdown bounty lost']

# %%
print(df.columns[[12, 18, 24, 25, 26, 27, 29, 47, 60]])
# Out:
# Index(['Level', 'CS in Team's Jungle', 'Vision Score', 'Wards placed',
#        'Wards destroyed', 'Control Wards Purchased', 'VSPM', 'GD@15',
#        'Total damage taken'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23070 entries, 0 to 23069
# Data columns (total 66 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GameID                              23070 non-null  int64
#  1   Team                                23070 non-null  object
#  2   Result                              23070 non-null  object
#  3   Game Time                           23070 non-null  object
#  4   Side                                23070 non-null  object
#  5   Patch                               23070 non-null  object
#  6   Tournament                          23070 non-null  object
#  7   Date                                23070 non-null  object
#  8   Region                              23070 non-null  object
#  9   Champion                            23070 non-null  object
#  10  Player                              23070 non-null  object
#  11  Role                                23070 non-null  object
#  12  Level                               23060 non-null  float64
#  13  Kills                               23070 non-null  int64
#  14  Deaths                              23070 non-null  int64
#  15  Assists                             23070 non-null  int64
#  16  KDA                                 23070 non-null  object
#  17  CS                                  23070 non-null  int64
#  18  CS in Team's Jungle                 23060 non-null  float64
#  19  CS in Enemy Jungle                  0 non-null      float64
#  20  CSM                                 23070 non-null  float64
#  21  Golds                               23070 non-null  int64
#  22  GPM                                 23070 non-null  int64
#  23  GOLD%                               23070 non-null  object
#  24  Vision Score                        23060 non-null  float64
#  25  Wards placed                        23060 non-null  float64
#  26  Wards destroyed                     23060 non-null  float64
#  27  Control Wards Purchased             23060 non-null  float64
#  28  Detector Wards Placed               14890 non-null  float64
#  29  VSPM                                23060 non-null  float64
#  30  WPM                                 23070 non-null  float64
#  31  VWPM                                23070 non-null  float64
#  32  WCPM                                23070 non-null  float64
#  33  VS%                                 23060 non-null  object
#  34  Total damage to Champion            23070 non-null  float64
#  35  Physical Damage                     23070 non-null  float64
#  36  Magic Damage                        23070 non-null  float64
#  37  True Damage                         23070 non-null  float64
#  38  DPM                                 23070 non-null  int64
#  39  DMG%                                23070 non-null  object
#  40  K+A Per Minute                      23070 non-null  float64
#  41  KP%                                 23070 non-null  object
#  42  Solo kills                          1737 non-null   float64
#  43  Double kills                        14890 non-null  float64
#  44  Triple kills                        14890 non-null  float64
#  45  Quadra kills                        14890 non-null  float64
#  46  Penta kills                         14890 non-null  float64
#  47  GD@15                               23060 non-null  float64
#  48  CSD@15                              14890 non-null  float64
#  49  XPD@15                              14890 non-null  float64
#  50  LVLD@15                             14890 non-null  float64
#  51  Objectives Stolen                   14890 non-null  float64
#  52  Damage dealt to turrets             14890 non-null  float64
#  53  Damage dealt to buildings           14890 non-null  float64
#  54  Total heal                          14890 non-null  float64
#  55  Total Heals On Teammates            14890 non-null  float64
#  56  Damage self mitigated               14890 non-null  float64
#  57  Total Damage Shielded On Teammates  14890 non-null  float64
#  58  Time ccing others                   14890 non-null  float64
#  59  Total Time CC Dealt                 14890 non-null  float64
#  60  Total damage taken                  23060 non-null  float64
#  61  Total Time Spent Dead               14890 non-null  float64
#  62  Consumables purchased               14890 non-null  float64
#  63  Items Purchased                     14890 non-null  float64
#  64  Shutdown bounty collected           14890 non-null  float64
#  65  Shutdown bounty lost                14890 non-null  float64
# dtypes: float64(42), int64(8), object(16)
# memory usage: 11.6+ MB

# %%
df = df[df["GameID"] != 63197]

# %%
df.isnull().sum()
# Out:
# GameID                          0
# Team                            0
# Result                          0
# Game Time                       0
# Side                            0
#                              ...
# Total Time Spent Dead        8170
# Consumables purchased        8170
# Items Purchased              8170
# Shutdown bounty collected    8170
# Shutdown bounty lost         8170
# Length: 66, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23060 entries, 0 to 23069
# Data columns (total 66 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   GameID                              23060 non-null  int64
#  1   Team                                23060 non-null  object
#  2   Result                              23060 non-null  object
#  3   Game Time                           23060 non-null  object
#  4   Side                                23060 non-null  object
#  5   Patch                               23060 non-null  object
#  6   Tournament                          23060 non-null  object
#  7   Date                                23060 non-null  object
#  8   Region                              23060 non-null  object
#  9   Champion                            23060 non-null  object
#  10  Player                              23060 non-null  object
#  11  Role                                23060 non-null  object
#  12  Level                               23060 non-null  float64
#  13  Kills                               23060 non-null  int64
#  14  Deaths                              23060 non-null  int64
#  15  Assists                             23060 non-null  int64
#  16  KDA                                 23060 non-null  object
#  17  CS                                  23060 non-null  int64
#  18  CS in Team's Jungle                 23060 non-null  float64
#  19  CS in Enemy Jungle                  0 non-null      float64
#  20  CSM                                 23060 non-null  float64
#  21  Golds                               23060 non-null  int64
#  22  GPM                                 23060 non-null  int64
#  23  GOLD%                               23060 non-null  object
#  24  Vision Score                        23060 non-null  float64
#  25  Wards placed                        23060 non-null  float64
#  26  Wards destroyed                     23060 non-null  float64
#  27  Control Wards Purchased             23060 non-null  float64
#  28  Detector Wards Placed               14890 non-null  float64
#  29  VSPM                                23060 non-null  float64
#  30  WPM                                 23060 non-null  float64
#  31  VWPM                                23060 non-null  float64
#  32  WCPM                                23060 non-null  float64
#  33  VS%                                 23060 non-null  object
#  34  Total damage to Champion            23060 non-null  float64
#  35  Physical Damage                     23060 non-null  float64
#  36  Magic Damage                        23060 non-null  float64
#  37  True Damage                         23060 non-null  float64
#  38  DPM                                 23060 non-null  int64
#  39  DMG%                                23060 non-null  object
#  40  K+A Per Minute                      23060 non-null  float64
#  41  KP%                                 23060 non-null  object
#  42  Solo kills                          1737 non-null   float64
#  43  Double kills                        14890 non-null  float64
#  44  Triple kills                        14890 non-null  float64
#  45  Quadra kills                        14890 non-null  float64
#  46  Penta kills                         14890 non-null  float64
#  47  GD@15                               23060 non-null  float64
#  48  CSD@15                              14890 non-null  float64
#  49  XPD@15                              14890 non-null  float64
#  50  LVLD@15                             14890 non-null  float64
#  51  Objectives Stolen                   14890 non-null  float64
#  52  Damage dealt to turrets             14890 non-null  float64
#  53  Damage dealt to buildings           14890 non-null  float64
#  54  Total heal                          14890 non-null  float64
#  55  Total Heals On Teammates            14890 non-null  float64
#  56  Damage self mitigated               14890 non-null  float64
#  57  Total Damage Shielded On Teammates  14890 non-null  float64
#  58  Time ccing others                   14890 non-null  float64
#  59  Total Time CC Dealt                 14890 non-null  float64
#  60  Total damage taken                  23060 non-null  float64
#  61  Total Time Spent Dead               14890 non-null  float64
#  62  Consumables purchased               14890 non-null  float64
#  63  Items Purchased                     14890 non-null  float64
#  64  Shutdown bounty collected           14890 non-null  float64
#  65  Shutdown bounty lost                14890 non-null  float64
# dtypes: float64(42), int64(8), object(16)
# memory usage: 11.8+ MB

# %%
df = df.dropna(axis=1)

# %%
df.head()
# Out:
#    GameID          Team Result Game Time  Side  Patch        Tournament  \
# 0   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 1   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 2   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 3   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
# 4   62896  Weibo Gaming    WIN     35:23  Blue  v15.1  LPL 2025 Split 1
#
#          Date Region Champion  ... Total damage to Champion Physical Damage  \
# 0  2025-01-12     CN   Ksante  ...                  9830.40         7914.28
# 1  2025-01-12     CN    Viego  ...                 10013.26         8758.59
# 2  2025-01-12     CN   Aurora  ...                 37571.06         1077.96
# 3  2025-01-12     CN     Ashe  ...                 15603.29        14094.30
# 4  2025-01-12     CN    Braum  ...                  6292.02          465.85
#
#    Magic Damage  True Damage   DPM   DMG% K+A Per Minute    KP%   GD@15  \
# 0       1012.28       903.84   278  12.4%           0.20  41.2%  -600.0
# 1       1070.67       184.00   283  12.6%           0.25  52.9%   528.0
# 2      35183.30      1309.80  1062  47.4%           0.37  76.5%  1072.0
# 3       1508.99         0.00   441  19.7%           0.25  52.9%  -199.0
# 4       5826.17         0.00   178   7.9%           0.34  70.6%   250.0
#
#    Total damage taken
# 0             26434.7
# 1             42723.7
# 2             16880.7
# 3             15290.8
# 4             17962.1
#
# [5 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23060 entries, 0 to 23069
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   GameID                    23060 non-null  int64
#  1   Team                      23060 non-null  object
#  2   Result                    23060 non-null  object
#  3   Game Time                 23060 non-null  object
#  4   Side                      23060 non-null  object
#  5   Patch                     23060 non-null  object
#  6   Tournament                23060 non-null  object
#  7   Date                      23060 non-null  object
#  8   Region                    23060 non-null  object
#  9   Champion                  23060 non-null  object
#  10  Player                    23060 non-null  object
#  11  Role                      23060 non-null  object
#  12  Level                     23060 non-null  float64
#  13  Kills                     23060 non-null  int64
#  14  Deaths                    23060 non-null  int64
#  15  Assists                   23060 non-null  int64
#  16  KDA                       23060 non-null  object
#  17  CS                        23060 non-null  int64
#  18  CS in Team's Jungle       23060 non-null  float64
#  19  CSM                       23060 non-null  float64
#  20  Golds                     23060 non-null  int64
#  21  GPM                       23060 non-null  int64
#  22  GOLD%                     23060 non-null  object
#  23  Vision Score              23060 non-null  float64
#  24  Wards placed              23060 non-null  float64
#  25  Wards destroyed           23060 non-null  float64
#  26  Control Wards Purchased   23060 non-null  float64
#  27  VSPM                      23060 non-null  float64
#  28  WPM                       23060 non-null  float64
#  29  VWPM                      23060 non-null  float64
#  30  WCPM                      23060 non-null  float64
#  31  VS%                       23060 non-null  object
#  32  Total damage to Champion  23060 non-null  float64
#  33  Physical Damage           23060 non-null  float64
#  34  Magic Damage              23060 non-null  float64
#  35  True Damage               23060 non-null  float64
#  36  DPM                       23060 non-null  int64
#  37  DMG%                      23060 non-null  object
#  38  K+A Per Minute            23060 non-null  float64
#  39  KP%                       23060 non-null  object
#  40  GD@15                     23060 non-null  float64
#  41  Total damage taken        23060 non-null  float64
# dtypes: float64(18), int64(8), object(16)
# memory usage: 7.6+ MB

# %%
df = df.drop(["KDA","CS in Team's Jungle", "CSM", "Physical Damage", "Magic Damage", "True Damage", "Total damage taken", "Total damage to Champion", "CS", "Vision Score", "Wards placed", "Wards destroyed", "Control Wards Purchased", "VSPM", "WPM", "WCPM", "VWPM" ], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23060 entries, 0 to 23069
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GameID          23060 non-null  int64
#  1   Team            23060 non-null  object
#  2   Result          23060 non-null  object
#  3   Game Time       23060 non-null  object
#  4   Side            23060 non-null  object
#  5   Patch           23060 non-null  object
#  6   Tournament      23060 non-null  object
#  7   Date            23060 non-null  object
#  8   Region          23060 non-null  object
#  9   Champion        23060 non-null  object
#  10  Player          23060 non-null  object
#  11  Role            23060 non-null  object
#  12  Level           23060 non-null  float64
#  13  Kills           23060 non-null  int64
#  14  Deaths          23060 non-null  int64
#  15  Assists         23060 non-null  int64
#  16  Golds           23060 non-null  int64
#  17  GPM             23060 non-null  int64
#  18  GOLD%           23060 non-null  object
#  19  VS%             23060 non-null  object
#  20  DPM             23060 non-null  int64
#  21  DMG%            23060 non-null  object
#  22  K+A Per Minute  23060 non-null  float64
#  23  KP%             23060 non-null  object
#  24  GD@15           23060 non-null  float64
# dtypes: float64(3), int64(7), object(15)
# memory usage: 4.6+ MB

# %%
df["Result"] = df["Result"].map({"WIN": 1, "LOSS": 0})

# %%
df["Champion"] = df["Champion"].str.replace(r"\bRek\b", "Reksai", regex=True)

# %%
df["Patch"] = df["Patch"].str.lstrip("v")

# %%
df["Side"] = df["Side"].map({"Blue": 1, "Red":  0})

# %%
df["Game Time"] = pd.to_timedelta("00:" + df["Game Time"])
df["Game Time"] = pd.to_timedelta(df["Game Time"]).dt.total_seconds()

# %%
df["KP%"] = (df["KP%"].str.rstrip("%").astype(float)/100).round(3)
df["GOLD%"] = (df["GOLD%"].str.rstrip("%").astype(float)/100).round(3)
df["VS%"] = (df["VS%"].str.rstrip("%").astype(float)/100).round(3)
df["DMG%"] = (df["DMG%"].str.rstrip("%").astype(float)/100).round(3)

# %%
numerical_cols = df.select_dtypes(include=["number"]).columns
correlation_matrix = df[numerical_cols].corr()

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
correlation_matrix
# Out:
#                       GameID        Result     Game Time          Side  \
# GameID          1.000000e+00 -2.837200e-15 -1.656746e-02 -2.858770e-16
# Result         -2.837200e-15  1.000000e+00  3.106198e-17  5.810928e-02
# Game Time      -1.656746e-02  3.106198e-17  1.000000e+00 -2.622799e-17
# Side           -2.858770e-16  5.810928e-02 -2.622799e-17  1.000000e+00
# Level           2.450335e-02  3.148600e-01  4.891917e-01  1.696135e-02
# Kills           1.512491e-02  3.910323e-01  1.208883e-01  1.973564e-02
# Deaths          2.086216e-02 -5.444732e-01  1.684966e-01 -2.729001e-02
# Assists         4.638319e-02  5.857661e-01  2.047657e-01  2.927260e-02
# Golds           6.899592e-03  3.112919e-01  5.695980e-01  2.057744e-02
# GPM             2.050263e-02  3.993992e-01 -8.691444e-03  2.787022e-02
# GOLD%          -1.700889e-05 -2.313420e-05 -3.563884e-05 -5.177654e-05
# VS%            -2.119955e-05  1.544318e-05 -3.334350e-06  3.124550e-05
# DPM             2.371697e-02  2.210790e-01  1.025962e-01  2.314299e-02
# DMG%            2.265102e-05  3.973357e-05  5.566413e-06 -2.132045e-05
# K+A Per Minute  5.234737e-02  6.931753e-01 -4.596292e-02  3.664669e-02
# KP%             3.846450e-02  1.128820e-01  8.344408e-02  9.122033e-03
# GD@15           1.695256e-17  2.969782e-01 -2.165035e-18  4.496608e-02
#
#                    Level     Kills    Deaths   Assists     Golds       GPM  \
# GameID          0.024503  0.015125  0.020862  0.046383  0.006900  0.020503
# Result          0.314860  0.391032 -0.544473  0.585766  0.311292  0.399399
# Game Time       0.489192  0.120888  0.168497  0.204766  0.569598 -0.008691
# Side            0.016961  0.019736 -0.027290  0.029273  0.020577  0.027870
# Level           1.000000  0.492203 -0.285056  0.091674  0.860022  0.721362
# Kills           0.492203  1.000000 -0.274264  0.100494  0.687913  0.758516
# Deaths         -0.285056 -0.274264  1.000000 -0.173013 -0.250919 -0.436315
# Assists         0.091674  0.100494 -0.173013  1.000000  0.085473 -0.017659
# Golds           0.860022  0.687913 -0.250919  0.085473  1.000000  0.806895
# GPM             0.721362  0.758516 -0.436315 -0.017659  0.806895  1.000000
# GOLD%           0.642296  0.598316 -0.246554 -0.343252  0.729998  0.883622
# VS%            -0.689532 -0.366455  0.160367  0.318710 -0.579381 -0.707210
# DPM             0.611823  0.658402 -0.223479  0.000280  0.697267  0.774184
# DMG%            0.548810  0.500506 -0.202283 -0.270437  0.602771  0.726860
# K+A Per Minute  0.187023  0.533900 -0.345082  0.838298  0.249031  0.363525
# KP%            -0.049186  0.201619 -0.086658  0.416903  0.071158  0.030295
# GD@15           0.144608  0.341974 -0.290718  0.184756  0.216122  0.286518
#
#                    GOLD%       VS%       DPM      DMG%  K+A Per Minute  \
# GameID         -0.000017 -0.000021  0.023717  0.000023        0.052347
# Result         -0.000023  0.000015  0.221079  0.000040        0.693175
# Game Time      -0.000036 -0.000003  0.102596  0.000006       -0.045963
# Side           -0.000052  0.000031  0.023143 -0.000021        0.036647
# Level           0.642296 -0.689532  0.611823  0.548810        0.187023
# Kills           0.598316 -0.366455  0.658402  0.500506        0.533900
# Deaths         -0.246554  0.160367 -0.223479 -0.202283       -0.345082
# Assists        -0.343252  0.318710  0.000280 -0.270437        0.838298
# Golds           0.729998 -0.579381  0.697267  0.602771        0.249031
# GPM             0.883622 -0.707210  0.774184  0.726860        0.363525
# GOLD%           1.000000 -0.803505  0.730817  0.822334       -0.004445
# VS%            -0.803505  1.000000 -0.613136 -0.694298        0.093818
# DPM             0.730817 -0.613136  1.000000  0.878264        0.289514
# DMG%            0.822334 -0.694298  0.878264  1.000000        0.009273
# K+A Per Minute -0.004445  0.093818  0.289514  0.009273        1.000000
# KP%            -0.014757  0.200745  0.057567  0.012606        0.425300
# GD@15           0.132494  0.018623  0.203890  0.114634        0.342386
#
#                      KP%         GD@15
# GameID          0.038464  1.695256e-17
# Result          0.112882  2.969782e-01
# Game Time       0.083444 -2.165035e-18
# Side            0.009122  4.496608e-02
# Level          -0.049186  1.446081e-01
# Kills           0.201619  3.419736e-01
# Deaths         -0.086658 -2.907181e-01
# Assists         0.416903  1.847565e-01
# Golds           0.071158  2.161225e-01
# GPM             0.030295  2.865185e-01
# GOLD%          -0.014757  1.324938e-01
# VS%             0.200745  1.862263e-02
# DPM             0.057567  2.038899e-01
# DMG%            0.012606  1.146341e-01
# K+A Per Minute  0.425300  3.423861e-01
# KP%             1.000000  1.499425e-01
# GD@15           0.149942  1.000000e+00

# %%
df.hist(bins=50, figsize=(60,20))
# Out:
# array([[<Axes: title={'center': 'GameID'}>,
#         <Axes: title={'center': 'Result'}>,
#         <Axes: title={'center': 'Game Time'}>,
#         <Axes: title={'center': 'Side'}>],
#        [<Axes: title={'center': 'Level'}>,
#         <Axes: title={'center': 'Kills'}>,
#         <Axes: title={'center': 'Deaths'}>,
#         <Axes: title={'center': 'Assists'}>],
#        [<Axes: title={'center': 'Golds'}>,
#         <Axes: title={'center': 'GPM'}>,
#         <Axes: title={'center': 'GOLD%'}>,
#         <Axes: title={'center': 'VS%'}>],
#        [<Axes: title={'center': 'DPM'}>,
#         <Axes: title={'center': 'DMG%'}>,
#         <Axes: title={'center': 'K+A Per Minute'}>,
#         <Axes: title={'center': 'KP%'}>],
#        [<Axes: title={'center': 'GD@15'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df
# Out:
#        GameID          Team  Result  Game Time  Side  Patch  \
# 0       62896  Weibo Gaming       1     2123.0     1   15.1
# 1       62896  Weibo Gaming       1     2123.0     1   15.1
# 2       62896  Weibo Gaming       1     2123.0     1   15.1
# 3       62896  Weibo Gaming       1     2123.0     1   15.1
# 4       62896  Weibo Gaming       1     2123.0     1   15.1
# ...       ...           ...     ...        ...   ...    ...
# 23065   72881     PSG Talon       0     1693.0     0  15.20
# 23066   72881     PSG Talon       0     1693.0     0  15.20
# 23067   72881     PSG Talon       0     1693.0     0  15.20
# 23068   72881     PSG Talon       0     1693.0     0  15.20
# 23069   72881     PSG Talon       0     1693.0     0  15.20
#
#                    Tournament        Date Region Champion   Player     Role  \
# 0            LPL 2025 Split 1  2025-01-12     CN   Ksante  Breathe      TOP
# 1            LPL 2025 Split 1  2025-01-12     CN    Viego     Tian   JUNGLE
# 2            LPL 2025 Split 1  2025-01-12     CN   Aurora   xiaohu      MID
# 3            LPL 2025 Split 1  2025-01-12     CN     Ashe    Light      ADC
# 4            LPL 2025 Split 1  2025-01-12     CN    Braum     Hang  SUPPORT
# ...                       ...         ...    ...      ...      ...      ...
# 23065  Worlds 2025 Main Event  2025-10-16     WR   Yorick     Azhi      TOP
# 23066  Worlds 2025 Main Event  2025-10-16     WR  Naafiri    Karsa   JUNGLE
# 23067  Worlds 2025 Main Event  2025-10-16     WR  Taliyah    Maple      MID
# 23068  Worlds 2025 Main Event  2025-10-16     WR  Caitlyn    Betty      ADC
# 23069  Worlds 2025 Main Event  2025-10-16     WR    Karma    Woody  SUPPORT
#
#        Level  Kills  Deaths  Assists  Golds  GPM  GOLD%    VS%   DPM   DMG%  \
# 0       18.0      4       0        3  14706  416  0.212  0.096   278  0.124
# 1       17.0      4       0        5  14586  412  0.210  0.165   283  0.126
# 2       18.0      5       1        8  15720  444  0.226  0.130  1062  0.474
# 3       16.0      3       2        6  14688  415  0.211  0.173   441  0.197
# 4       14.0      1       2       11   9762  276  0.141  0.436   178  0.079
# ...      ...    ...     ...      ...    ...  ...    ...    ...   ...    ...
# 23065   14.0      1       4        3  10188  361  0.222  0.132   652  0.337
# 23066   13.0      2       3        3   9380  332  0.204  0.123   359  0.186
# 23067   13.0      1       3        4   9205  326  0.201  0.119   374  0.194
# 23068   14.0      2       3        1  10929  387  0.238  0.145   364  0.189
# 23069   10.0      0       3        4   6190  219  0.135  0.480   183  0.095
#
#        K+A Per Minute    KP%   GD@15
# 0                0.20  0.412  -600.0
# 1                0.25  0.529   528.0
# 2                0.37  0.765  1072.0
# 3                0.25  0.529  -199.0
# 4                0.34  0.706   250.0
# ...               ...    ...     ...
# 23065            0.14  0.667   292.0
# 23066            0.18  0.833   444.0
# 23067            0.18  0.833  -531.0
# 23068            0.11  0.500   533.0
# 23069            0.14  0.667   271.0
#
# [23060 rows x 25 columns]

# %%
# fix team names for anyone's legend and psg talon has renamed themselves
df["Team"] = df["Team"].str.replace("anyone s legend", "Anyones Legend", case=False)
df['Team'] = df['Team'].str.replace('^talon$', 'PSG Talon', case=False, regex=True)

# %%
team_stats = df.groupby(["GameID", "Team"], as_index=False).agg({
    "Date": "first",
    "Region": "first",
    "Kills": "sum",
    "Deaths": "sum",
    "Assists": "sum",
    "Result": "first",
    "Game Time": "first",
    "Side": "first",
    "Patch": "first",
    "GD@15": "sum"
})

# %%
champions_per_role = df.groupby(["GameID", "Team", "Role"])["Champion"].first().unstack()
champions_per_role.columns = [f"{role}_champion" for role in champions_per_role.columns]

# %%
player_per_role = df.groupby(["GameID", "Team", "Role"])["Player"].first().unstack()
player_per_role.columns = [f"{role}_player" for role in player_per_role.columns]

# %%
kills_per_role = df.groupby(["GameID", "Team", "Role"])["Kills"].first().unstack()
kills_per_role.columns = [f"{role}_kills" for role in kills_per_role.columns]

# %%
assists_per_role = df.groupby(["GameID", "Team", "Role"])["Assists"].first().unstack()
assists_per_role.columns = [f"{role}_assists" for role in assists_per_role.columns]

# %%
deaths_per_role = df.groupby(["GameID", "Team", "Role"])["Deaths"].first().unstack()
deaths_per_role.columns = [f"{role}_deaths" for role in deaths_per_role.columns]

# %%
kp_per_role = df.groupby(["GameID", "Team", "Role"])["KP%"].first().unstack()
kp_per_role.columns = [f"{role}_kp%" for role in kp_per_role.columns]

# %%
dmg_per_role = df.groupby(["GameID", "Team", "Role"])["DMG%"].first().unstack()
dmg_per_role.columns = [f"{role}_dmg%" for role in dmg_per_role.columns]

# %%
ka_per_role = df.groupby(["GameID", "Team", "Role"])["K+A Per Minute"].first().unstack()
ka_per_role.columns = [f"{role}_ka_per_minute" for role in ka_per_role.columns]

# %%
gd_per_role = df.groupby(["GameID", "Team", "Role"])["GD@15"].first().unstack()
gd_per_role.columns = [f"{role}_gd@15" for role in gd_per_role.columns]

# %%
team_stats = (team_stats.merge(champions_per_role, on=["GameID", "Team"], how="left")
             .merge(player_per_role, on=["GameID", "Team"], how="left")
             .merge(kills_per_role, on=["GameID", "Team"], how="left")
             .merge(assists_per_role, on=["GameID", "Team"], how="left")
             .merge(deaths_per_role, on=["GameID", "Team"], how="left")
             .merge(kp_per_role, on=["GameID", "Team"], how="left")
             .merge(dmg_per_role, on=["GameID", "Team"], how="left")
             .merge(ka_per_role, on=["GameID", "Team"], how="left")
             .merge(gd_per_role, on=["GameID", "Team"], how="left")
             )

# %%
team_stats
# Out:
#       GameID                 Team        Date Region  Kills  Deaths  Assists  \
# 0      62896                  OMG  2025-01-12     CN      5      17        9
# 1      62896         Weibo Gaming  2025-01-12     CN     17       5       33
# 2      62897                  OMG  2025-01-12     CN     11      18       27
# 3      62897         Weibo Gaming  2025-01-12     CN     18      11       40
# 4      62898                  OMG  2025-01-12     CN     18      22       40
# ...      ...                  ...         ...    ...    ...     ...      ...
# 4607   72879        Gen.G eSports  2025-10-16     WR     10      16       24
# 4608   72880      Bilibili Gaming  2025-10-16     WR     14       6       41
# 4609   72880               Fnatic  2025-10-16     WR      6      14       15
# 4610   72881  Hanwha Life eSports  2025-10-16     WR     16       6       41
# 4611   72881            PSG Talon  2025-10-16     WR      6      16       15
#
#       Result  Game Time  Side  Patch   GD@15  ADC_champion JUNGLE_champion  \
# 0          0     2123.0     0   15.1 -1051.0         Varus        Nocturne
# 1          1     2123.0     1   15.1  1051.0          Ashe           Viego
# 2          0     1952.0     1   15.1 -2888.0          Jhin          Maokai
# 3          1     1952.0     0   15.1  2888.0  Miss Fortune          Wukong
# 4          0     2014.0     1   15.1  2460.0         Ziggs            Zyra
# ...      ...        ...   ...    ...     ...           ...             ...
# 4607       0     1935.0     1  15.20  -322.0         Kaisa        Xin Zhao
# 4608       1     1673.0     1  15.20  2064.0         Xayah         Naafiri
# 4609       0     1673.0     0  15.20 -2064.0       Caitlyn              Vi
# 4610       1     1693.0     1  15.20 -1009.0        Ezreal              Vi
# 4611       0     1693.0     0  15.20  1009.0       Caitlyn         Naafiri
#
#      MID_champion SUPPORT_champion TOP_champion ADC_player JUNGLE_player  \
# 0         Orianna            Neeko         Gnar     Starry          Heng
# 1          Aurora            Braum       Ksante      Light          Tian
# 2         Ambessa             Rell       Rumble     Starry          Heng
# 3          Viktor            Rakan        Jayce      Light          Tian
# 4            Yone            Leona       Aatrox     Starry          Heng
# ...           ...              ...          ...        ...           ...
# 4607         Ryze          Alistar       Ksante      Ruler        Canyon
# 4608      Orianna            Rakan     Renekton        Elk        Shad0w
# 4609       Aurora          Morgana        Poppy      Upset        Razork
# 4610       Aurora             Bard      Ambessa      Viper        Peanut
# 4611      Taliyah            Karma       Yorick      Betty         Karsa
#
#      MID_player SUPPORT_player TOP_player  ADC_kills  JUNGLE_kills  MID_kills  \
# 0       Linfeng          Moham       Hery          2             2          0
# 1        xiaohu           Hang    Breathe          3             4          5
# 2       Linfeng          Moham       Hery          0             1          4
# 3        xiaohu           Hang    Breathe          4             6          1
# 4       Linfeng          Moham       Hery          5             6          6
# ...         ...            ...        ...        ...           ...        ...
# 4607      Chovy           Duro       Kiin          6             1          3
# 4608     Knight             ON        Bin          2             6          2
# 4609       Poby          Mikyx  Oscarinin          5             0          1
# 4610       Zeka        Delight       Zeus          2             3          7
# 4611      Maple          Woody       Azhi          2             2          1
#
#       SUPPORT_kills  TOP_kills  ADC_assists  JUNGLE_assists  MID_assists  \
# 0                 0          1            2               1            3
# 1                 1          4            6               5            8
# 2                 0          6            5               7            2
# 3                 2          5            9               6            7
# 4                 0          1            9               9            4
# ...             ...        ...          ...             ...          ...
# 4607              0          0            2               5            5
# 4608              0          4            8               6            8
# 4609              0          0            1               5            0
# 4610              0          4            8               8            5
# 4611              0          1            1               3            4
#
#       SUPPORT_assists  TOP_assists  ADC_deaths  JUNGLE_deaths  MID_deaths  \
# 0                   3            0           4              4           3
# 1                  11            3           2              0           1
# 2                   9            4           3              6           4
# 3                  11            7           1              2           3
# 4                  13            5           3              6           6
# ...               ...          ...         ...            ...         ...
# 4607                6            6           2              5           3
# 4608               14            5           2              1           1
# 4609                5            4           3              3           1
# 4610               12            8           0              1           1
# 4611                4            3           3              3           3
#
#       SUPPORT_deaths  TOP_deaths  ADC_kp%  JUNGLE_kp%  MID_kp%  SUPPORT_kp%  \
# 0                  4           2    0.800       0.600    0.600        0.600
# 1                  2           0    0.529       0.529    0.765        0.706
# 2                  4           1    0.455       0.727    0.545        0.818
# 3                  2           3    0.722       0.667    0.444        0.722
# 4                  3           4    0.778       0.833    0.556        0.722
# ...              ...         ...      ...         ...      ...          ...
# 4607               5           1    0.800       0.600    0.800        0.600
# 4608               1           1    0.714       0.857    0.714        1.000
# 4609               6           1    1.000       0.833    0.167        0.833
# 4610               1           3    0.625       0.688    0.750        0.750
# 4611               3           4    0.500       0.833    0.833        0.667
#
#       TOP_kp%  ADC_dmg%  JUNGLE_dmg%  MID_dmg%  SUPPORT_dmg%  TOP_dmg%  \
# 0       0.200     0.213        0.146     0.231         0.147     0.262
# 1       0.412     0.197        0.126     0.474         0.079     0.124
# 2       0.909     0.097        0.213     0.243         0.056     0.390
# 3       0.667     0.316        0.157     0.306         0.044     0.178
# 4       0.333     0.314        0.285     0.166         0.091     0.144
# ...       ...       ...          ...       ...           ...       ...
# 4607    0.600     0.243        0.170     0.334         0.049     0.204
# 4608    0.643     0.276        0.184     0.269         0.069     0.201
# 4609    0.667     0.363        0.158     0.137         0.110     0.231
# 4610    0.750     0.258        0.123     0.246         0.062     0.311
# 4611    0.667     0.189        0.186     0.194         0.095     0.337
#
#       ADC_ka_per_minute  JUNGLE_ka_per_minute  MID_ka_per_minute  \
# 0                  0.11                  0.08               0.08
# 1                  0.25                  0.25               0.37
# 2                  0.15                  0.25               0.18
# 3                  0.40                  0.37               0.25
# 4                  0.42                  0.45               0.30
# ...                 ...                   ...                ...
# 4607               0.25                  0.19               0.25
# 4608               0.36                  0.43               0.36
# 4609               0.22                  0.18               0.04
# 4610               0.35                  0.39               0.43
# 4611               0.11                  0.18               0.18
#
#       SUPPORT_ka_per_minute  TOP_ka_per_minute  ADC_gd@15  JUNGLE_gd@15  \
# 0                      0.08               0.03      199.0        -528.0
# 1                      0.34               0.20     -199.0         528.0
# 2                      0.28               0.31    -1727.0         197.0
# 3                      0.40               0.37     1727.0        -197.0
# 4                      0.39               0.18      672.0         936.0
# ...                     ...                ...        ...           ...
# 4607                   0.19               0.19      738.0        -311.0
# 4608                   0.50               0.32      467.0         356.0
# 4609                   0.18               0.14     -467.0        -356.0
# 4610                   0.43               0.43     -533.0        -444.0
# 4611                   0.14               0.14      533.0         444.0
#
#       MID_gd@15  SUPPORT_gd@15  TOP_gd@15
# 0       -1072.0         -250.0      600.0
# 1        1072.0          250.0     -600.0
# 2        -922.0         -245.0     -191.0
# 3         922.0          245.0      191.0
# 4         178.0         1077.0     -403.0
# ...         ...            ...        ...
# 4607     -838.0         -408.0      497.0
# 4608      349.0          226.0      666.0
# 4609     -349.0         -226.0     -666.0
# 4610      531.0         -271.0     -292.0
# 4611     -531.0          271.0      292.0
#
# [4612 rows x 57 columns]

# %%
team_stats['Patch'] = team_stats['Patch'].astype(str)
team_stats.to_csv("combined_team_match_history.csv", index=False)
